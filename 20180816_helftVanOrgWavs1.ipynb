# %%
# %reload_ext autoreload
# %autoreload 2
import glob
import importlib
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import scipy.io.wavfile as wv
import scipy.signal as sig
import wave

from datetime import datetime
from keras.models import Sequential, load_model
from keras.layers import Dense

from util import util
from util import WavFileParts
from util.logUtil import LOG, LOG_HEADER
from util.confusionMatrix import ConfusionMatrix
# Out:
# /opt/miniconda2/envs/py36h2o/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### globale settings

# %%
classes = ['music', 'voice', 'environment']

macDir = '/Volumes/SAA_DATA/datasets/'
winDir = 'E:/SAA_DATA/'
osDir = macDir
recordingDir = osDir + '/localizationRecordings'

if osDir == winDir:
    storageFolder = 'E:/SAA_DATA/storedData/'
else:
    storageFolder = '/Users/etto/Desktop/storedData/'

baseSrcDir = osDir + 'localizationFiles/20171025AllExtractionsMic4'
orgWavDirs1 = ['G428_0.0_1.4',
              'G527_0.5_1.4',
              'Studio_2.0_4.2'
              ]

orgWavDirs2 = ['G428_2.1_2.4',
              'G527_1.2_5.8',
              'Studio_3.0_2.0'
              ]

NFFT = 1024

chunksBaseDir = 'chunks'
rooms = ['Studio', 'G428', 'G527']

# %% [markdown]
# ### utility functies

# %%
def readSoundChunksDynamic(moduleString):
    chunks = importlib.import_module(moduleString).soundChunks
    wfPts = []
    for jsonString in chunks:
        wfPts.append(WavFileParts.WavFilePartFromJson(jsonString))
    return wfPts

def timeFunction(func):
    """
    Aanroep: bijv. fpc = timeFunction(lambda: getFilesPerCategory(srcDir))
    """
    startTime = datetime.now()
    print('Start: ' + startTime.strftime('%H:%M:%S') + '\n=================')

    res = func()
    
    endTime = datetime.now()
    print('\n=================\nEnd: ' + endTime.strftime('%H:%M:%S'))
    print('Time taken: '),
    print(endTime - startTime)
    print()
    
    return res
    
def storeTestData(allSpectros, allClasses, storageName, keyName):
    filename = storageFolder + storageName + '.hd5'
    df = pd.DataFrame(allSpectros)
    df.to_hdf(path_or_buf=filename, key='spectros_' + keyName)

    df = pd.DataFrame(allClasses)
    df.to_hdf(path_or_buf=filename, key='classes_' + keyName)

def retrieveTestData(storageName, keyName):
    filename = storageFolder + storageName + '.hd5'
    specDf = pd.read_hdf(path_or_buf=filename, key='spectros_' + keyName)
    classesDf = pd.read_hdf(path_or_buf=filename, key='classes_' + keyName)
    return specDf.values, classesDf.values

# %% [markdown]
# ### functies tbv trainen

# %%
# Maakt een dictionary aan; per categorie alle files (volledig pad) uit de srcDir
# srcDir is een van de orgWavDirs, bijvoorbeeld
#    localizationFiles/20171025AllExtractionsMic4/G428_0.0_1.4
def getFilesPerCategory(srcDir):
    filesPerCategory = {}
    for catDirLong in glob.glob(srcDir + '/*'):
        catDir = catDirLong.replace('\\', '/')
        catDir = catDir.replace(srcDir + '/', '')

        filesPerCategory[catDir] = []
        for filename in glob.glob(catDirLong + '/*'):
            filename = filename.replace('\\','/')
            filesPerCategory[catDir].append(filename)
    return filesPerCategory

def getFilesPerCatFromMultipleDirs(srcDirs, srcDirsBase=''):
    filesPerCat = {}
    for dirName in srcDirs:
        srcDir = srcDirsBase + '/' + dirName
        fpcNw = getFilesPerCategory(srcDir)
        if not filesPerCat:
            filesPerCat = fpcNw
        else:
            for key in filesPerCat:
                filesPerCat[key] += fpcNw[key]
    return filesPerCat

# %%
# Maakt een dictionary aan; per categorie de spectrogrammen
def getSpectrosFromFilesPerCategory(filesPerCategory):
    spectros = {}
    for clz in classes:
        spectros[clz] = []
        for filename in filesPerCategory[clz]:
            fs, signal = wv.read(filename)
            freq_array, segment_times, spectrogram = sig.spectrogram(x=signal, fs=fs, nfft=NFFT, noverlap=0)
            spectros[clz].append(spectrogram.T)
    return spectros

# %%
def getClassLengths(spectrosPerCat):
    clzLengths = {}
    for clz in classes:
        clzLengths[clz] = sum([np.shape(lst)[0] for lst in spectrosPerCat[clz]])
    return clzLengths

# %%
# verwacht invoer van getSpectrosFromFilesPerCategory
# levert traindata op (X_train en Y_train)
def createTrainDataFromSpectros(spectrosPerCat, clzLengths):
    X_train = np.concatenate(spectrosPerCat[classes[0]], axis=0)
    for i in range(1, len(classes)):
        nwSpectros = np.concatenate(spectrosPerCat[classes[i]], axis=0)
        X_train = np.concatenate((X_train,nwSpectros), axis=0)
    
    # one-hot encoding voor Y_train
    nrFiles = clzLengths[classes[0]]
    Y_train = np.array((np.ones(nrFiles),np.zeros(nrFiles), np.zeros(nrFiles))).T

    nrFiles = clzLengths[classes[1]]
    Y_train_nw = np.array((np.zeros(nrFiles), np.ones(nrFiles), np.zeros(nrFiles))).T
    Y_train = np.concatenate((Y_train, Y_train_nw),axis=0)

    nrFiles = clzLengths[classes[2]]
    Y_train_nw = np.array((np.zeros(nrFiles), np.zeros(nrFiles), np.ones(nrFiles))).T
    Y_train = np.concatenate((Y_train, Y_train_nw),axis=0)
    
    return X_train, Y_train

# %% [markdown]
# ### deep learning model

# %%
def create_model(layersizes):
    # create model
    model = Sequential()
    model.add(Dense(layersizes[0], input_dim=513, activation='relu'))
    for lsize in layersizes[1:]:
        model.add(Dense(lsize, activation='relu'))
    model.add(Dense(3, activation='softmax'))
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
def getModelFileName(modelFilePath, baseModelFilename, layers, nrEpochs):
    modelFilename = modelFilePath + baseModelFilename
    for lsize in layers:
        modelFilename = '{}_{}'.format(modelFilename, lsize)
    modelFilename += 'ep{}'.format(nrEpochs)
    modelFilename += '.hd5'
    return modelFilename

# %%
def getModelName(baseModelFilename, layers, nrEpochs):
    modelFilename = baseModelFilename
    for lsize in layers:
        modelFilename = '{}_{}'.format(modelFilename, lsize)
    modelFilename += 'ep{}'.format(nrEpochs)
    return modelFilename

# %%
def train_model(X_train, Y_train, layers, nrEpochs, modelFilePath, baseModelFilename):
    soundModel = create_model(layers)
    history = timeFunction(lambda: soundModel.fit(X_train,Y_train, epochs=nrEpochs, shuffle=True, verbose=1))
    soundModel.save(getModelFileName(modelFilePath, baseModelFilename, layers, nrEpochs))
    plt.plot(history.history['loss'])
    plt.show()

# %%
def evaluate_model(X_test, realClasses, layers, nrEpochs, modelFilePath, baseModelFilename):
    soundModel = load_model(getModelFileName(modelFilePath, baseModelFilename, layers, nrEpochs))

    # predicted classes
    predictions = soundModel.predict(X_test)
    predClasses = predictions.argmax(axis=1)

    matrix = ConfusionMatrix(classes)
    for vals in zip(realClasses, predClasses):
        matrix.add(int(vals[0]), int(vals[1]), 1)
    LOG(matrix.toString(),True)
    LOG('', True)
    LOG(matrix.toF1String(), True)
    return matrix

# %%
def train_and_evaluate_per_epoch(X_train, Y_train, realClasses, layers, nrEpochs, modelFilePath, baseModelFilename):
    soundModel = create_model(layers)
    for epNr in range(1, nrEpochs+1):
        LOG('\n*****************\n* Epoch nr {}\n*****************\n'.format(epNr), True)
        soundModel.fit(X_train,Y_train, epochs=1, shuffle=True, verbose=1)
        soundModel.save(getModelFileName(modelFilePath, baseModelFilename, layers, epNr))
        evaluate_model(X_train, realClasses, layers, epNr, modelFilePath, baseModelFilename)

# %% [markdown]
# ### trainen van model : alleen orgWavDirs1

# %%
# bepaal train data
# srcDir = baseSrcDir + '/' + orgWavDirs1[0]
# fpc = getFilesPerCategory(srcDir)
fpc = getFilesPerCatFromMultipleDirs(orgWavDirs1, baseSrcDir)
spcs = getSpectrosFromFilesPerCategory(fpc)
clzLengths = getClassLengths(spcs)
X_train, Y_train = createTrainDataFromSpectros(spcs, clzLengths)
# real train classes
realTrainClasses = np.concatenate((np.zeros(clzLengths[classes[0]]), 
                              np.ones(clzLengths[classes[1]]), 
                              2*np.ones(clzLengths[classes[2]])))

# %%
baseModelFilename = '20180816_orgsHelft1'
modelFilePath = storageFolder
logPrefix = 'Orgs helft 1'

# %%
layers = [100, 20]

LOG_HEADER(logPrefix + ', lagen: [100, 20]', True)

nrEpochs = 5
train_and_evaluate_per_epoch(X_train, Y_train, realTrainClasses, layers, nrEpochs, modelFilePath, baseModelFilename)
# Out:
# ####################################
# #
# # Orgs helft 1, lagen: [100, 20]
# #
# ####################################
#
#
# *****************
# * Epoch nr 1
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 43s 77us/step - loss: 0.2234 - acc: 0.9176
#                    m       v       e |  sens   acc
# music         166836   15013     660 |  0.91  0.96
# voice           4306  173966    4805 |  0.95  0.94
# environment      625    7509  181267 |  0.96  0.98
# --------------------------------------
# prec            0.97    0.89    0.97
#
# F1 overall: 0.94
# F1 music: 0.94
# F1 voice: 0.92
# F1 environment: 0.96
#
#
# *****************
# * Epoch nr 2
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 41s 74us/step - loss: 0.1413 - acc: 0.9479
#                    m       v       e |  sens   acc
# music         172183    9703     623 |  0.94  0.97
# voice           5667  172425    4985 |  0.94  0.96
# environment      374    3964  185063 |  0.98  0.98
# --------------------------------------
# prec            0.97    0.93    0.97
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.97
#
#
# *****************
# * Epoch nr 3
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 40s 72us/step - loss: 0.1193 - acc: 0.9554
#                    m       v       e |  sens   acc
# music         170729   11265     515 |  0.94  0.97
# voice           3093  175912    4072 |  0.96  0.96
# environment      286    3879  185236 |  0.98  0.98
# --------------------------------------
# prec            0.98    0.92    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.94
# F1 environment: 0.98
#
#
# *****************
# * Epoch nr 4
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 42s 76us/step - loss: 0.1092 - acc: 0.9590
#                    m       v       e |  sens   acc
# music         172832    9444     233 |  0.95  0.98
# voice           3322  177199    2556 |  0.97  0.96
# environment      413    5143  183845 |  0.97  0.98
# --------------------------------------
# prec            0.98    0.92    0.99
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.95
# F1 environment: 0.98
#
#
# *****************
# * Epoch nr 5
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 44s 79us/step - loss: 0.1026 - acc: 0.9617
#                    m       v       e |  sens   acc
# music         175193    6943     373 |  0.96  0.98
# voice           5081  174217    3779 |  0.95  0.97
# environment      250    3176  185975 |  0.98  0.99
# --------------------------------------
# prec            0.97    0.95    0.98
#
# F1 overall: 0.96
# F1 music: 0.97
# F1 voice: 0.95
# F1 environment: 0.98

# %%
layers = [400, 250, 100, 20]

LOG_HEADER(logPrefix + ', lagen: [400, 250, 100, 20]', True)

nrEpochs = 5
train_and_evaluate_per_epoch(X_train, Y_train, realTrainClasses, layers, nrEpochs, modelFilePath, baseModelFilename)
# Out:
# ####################################
# #
# # Orgs helft 1, lagen: [400, 250, 100, 20]
# #
# ####################################
#
#
# *****************
# * Epoch nr 1
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 115s 208us/step - loss: 0.1765 - acc: 0.9345
#                    m       v       e |  sens   acc
# music         169999   11888     622 |  0.93  0.97
# voice           4388  176369    2320 |  0.96  0.95
# environment      394    7813  181194 |  0.96  0.98
# --------------------------------------
# prec            0.97    0.90    0.98
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.97
#
#
# *****************
# * Epoch nr 2
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 115s 207us/step - loss: 0.1174 - acc: 0.9561
#                    m       v       e |  sens   acc
# music         172075   10077     357 |  0.94  0.97
# voice           3647  174493    4937 |  0.95  0.96
# environment      351    2628  186422 |  0.98  0.99
# --------------------------------------
# prec            0.98    0.93    0.97
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.94
# F1 environment: 0.98
#
#
# *****************
# * Epoch nr 3
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 121s 218us/step - loss: 0.1039 - acc: 0.9614
#                    m       v       e |  sens   acc
# music         175479    6565     465 |  0.96  0.98
# voice           5337  175040    2700 |  0.96  0.97
# environment      222    4118  185061 |  0.98  0.99
# --------------------------------------
# prec            0.97    0.94    0.98
#
# F1 overall: 0.96
# F1 music: 0.97
# F1 voice: 0.95
# F1 environment: 0.98
#
#
# *****************
# * Epoch nr 4
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 97s 174us/step - loss: 0.0964 - acc: 0.9642
#                    m       v       e |  sens   acc
# music         173441    8884     184 |  0.95  0.98
# voice           2377  178495    2205 |  0.97  0.97
# environment      299    4371  184731 |  0.98  0.99
# --------------------------------------
# prec            0.98    0.93    0.99
#
# F1 overall: 0.97
# F1 music: 0.97
# F1 voice: 0.95
# F1 environment: 0.98
#
#
# *****************
# * Epoch nr 5
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 95s 171us/step - loss: 0.0912 - acc: 0.9664
#                    m       v       e |  sens   acc
# music         177560    4759     190 |  0.97  0.98
# voice           6650  171932    4495 |  0.94  0.97
# environment      217    1945  187239 |  0.99  0.99
# --------------------------------------
# prec            0.96    0.96    0.98
#
# F1 overall: 0.97
# F1 music: 0.97
# F1 voice: 0.95
# F1 environment: 0.98

# %%
layers = [400, 300, 200, 100, 50, 20, 10]

LOG_HEADER(logPrefix + ', lagen: [400, 300, 200, 100, 50, 20, 10]', True)

nrEpochs = 5
train_and_evaluate_per_epoch(X_train, Y_train, realTrainClasses, layers, nrEpochs, modelFilePath, baseModelFilename)
# Out:
# ####################################
# #
# # Orgs helft 1, lagen: [400, 300, 200, 100, 50, 20, 10]
# #
# ####################################
#
#
# *****************
# * Epoch nr 1
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 117s 211us/step - loss: 0.1771 - acc: 0.9347
#                    m       v       e |  sens   acc
# music         171334   10815     360 |  0.94  0.97
# voice           3928  174959    4190 |  0.96  0.96
# environment      571    5285  183545 |  0.97  0.98
# --------------------------------------
# prec            0.97    0.92    0.98
#
# F1 overall: 0.95
# F1 music: 0.96
# F1 voice: 0.94
# F1 environment: 0.97
#
#
# *****************
# * Epoch nr 2
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 113s 204us/step - loss: 0.1208 - acc: 0.9556
#                    m       v       e |  sens   acc
# music         173546    8647     316 |  0.95  0.98
# voice           4017  175382    3678 |  0.96  0.96
# environment      539    3754  185108 |  0.98  0.99
# --------------------------------------
# prec            0.97    0.93    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.95
# F1 environment: 0.98
#
#
# *****************
# * Epoch nr 3
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 113s 203us/step - loss: 0.1081 - acc: 0.9606
#                    m       v       e |  sens   acc
# music         177757    4354     398 |  0.97  0.97
# voice           9252  170003    3822 |  0.93  0.96
# environment      689    3281  185431 |  0.98  0.99
# --------------------------------------
# prec            0.95    0.96    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.94
# F1 environment: 0.98
#
#
# *****************
# * Epoch nr 4
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 127s 230us/step - loss: 0.1009 - acc: 0.9632
#                    m       v       e |  sens   acc
# music         171039   10946     524 |  0.94  0.98
# voice           2095  177001    3981 |  0.97  0.97
# environment      234    2401  186766 |  0.99  0.99
# --------------------------------------
# prec            0.99    0.93    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.95
# F1 environment: 0.98
#
#
# *****************
# * Epoch nr 5
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 120s 216us/step - loss: 0.0946 - acc: 0.9652
#                    m       v       e |  sens   acc
# music         174991    7124     394 |  0.96  0.98
# voice           3113  174866    5098 |  0.96  0.97
# environment      190    1985  187226 |  0.99  0.99
# --------------------------------------
# prec            0.98    0.95    0.97
#
# F1 overall: 0.97
# F1 music: 0.97
# F1 voice: 0.95
# F1 environment: 0.98

# %%
layers = [450, 400, 350, 300, 250, 200, 150, 100, 50, 21]

LOG_HEADER(logPrefix + ', lagen: [450, 400, 350, 300, 250, 200, 150, 100, 50, 21]', True)

nrEpochs = 5
train_and_evaluate_per_epoch(X_train, Y_train, realTrainClasses, layers, nrEpochs, modelFilePath, baseModelFilename)
# Out:
# ####################################
# #
# # Orgs helft 1, lagen: [450, 400, 350, 300, 250, 200, 150, 100, 50, 21]
# #
# ####################################
#
#
# *****************
# * Epoch nr 1
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 232s 418us/step - loss: 0.1955 - acc: 0.9297
#                    m       v       e |  sens   acc
# music         168214   13868     427 |  0.92  0.97
# voice           2212  177480    3385 |  0.97  0.95
# environment      666    6905  181830 |  0.96  0.98
# --------------------------------------
# prec            0.98    0.90    0.98
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.97
#
#
# *****************
# * Epoch nr 2
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 230s 415us/step - loss: 0.1364 - acc: 0.9519
#                    m       v       e |  sens   acc
# music         173825    8122     562 |  0.95  0.97
# voice           7344  172741    2992 |  0.94  0.95
# environment      554    6560  182287 |  0.96  0.98
# --------------------------------------
# prec            0.96    0.92    0.98
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.97
#
#
# *****************
# * Epoch nr 3
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 289s 521us/step - loss: 0.1233 - acc: 0.9564
#                    m       v       e |  sens   acc
# music         171674   10581     254 |  0.94  0.97
# voice           2837  177781    2459 |  0.97  0.96
# environment      604    5863  182934 |  0.97  0.98
# --------------------------------------
# prec            0.98    0.92    0.99
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.94
# F1 environment: 0.98
#
#
# *****************
# * Epoch nr 4
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 305s 550us/step - loss: 0.1451 - acc: 0.9536
#                    m       v       e |  sens   acc
# music         171534   10798     177 |  0.94  0.96
# voice           8674  171442    2961 |  0.94  0.95
# environment     1009    4793  183599 |  0.97  0.98
# --------------------------------------
# prec            0.95    0.92    0.98
#
# F1 overall: 0.95
# F1 music: 0.94
# F1 voice: 0.93
# F1 environment: 0.98
#
#
# *****************
# * Epoch nr 5
# *****************
#
# Epoch 1/1
# 554987/554987 [==============================] - 250s 451us/step - loss: 0.1236 - acc: 0.9589
#                    m       v       e |  sens   acc
# music         173798    7881     830 |  0.95  0.98
# voice           4386  175044    3647 |  0.96  0.96
# environment      295    3706  185400 |  0.98  0.98
# --------------------------------------
# prec            0.97    0.94    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.95
# F1 environment: 0.98

# %% [markdown]
# ### functies tbv testen

# %%
def createAndStoreTestData(wavFileParts, baseDir, fileDate, micNr, storeFilename, keyName):
    allSpectros = np.array([])
    allClasses = np.array([])

    for wfPt in wavFileParts: #type: WavFilePart
        if not 'Gunshot' in wfPt.getSoundType():
            filename = baseDir + '/{:d}_{:d}_mono{:d}.wav'.format(fileDate, wfPt.fileNr, micNr)
            fs, signal = wv.read(filename)

            classNr = classes.index(wfPt.getSoundType().lower())
            for soundChunk in wfPt.getSoundChunks(micNr):
                startFrame = int(soundChunk[0] * fs)
                endFrame = int(soundChunk[1] * fs)

                sigChunk = signal[startFrame: endFrame]
                freq_array, segment_times, spectrogram = sig.spectrogram(x=sigChunk, fs=fs, nfft=NFFT, noverlap=0)
                if len(allSpectros) == 0:
                    allSpectros = spectrogram.T
                else:
                    allSpectros = np.append(allSpectros, spectrogram.T, axis=0)
                allClasses = np.append(allClasses, classNr * np.ones(len(segment_times)))
                
    storeTestData(allSpectros, allClasses, storeFilename, keyName)

# %% [markdown]
# ## maak spectra voor testdata

# %%
LOG_HEADER('maak spectra voor testdata Studio', True)
wvPts = readSoundChunksDynamic('chunks.Studio.soundChunks')
baseDir = recordingDir + '/20171011'
fileDate = 170816
filename = 'testData_Studio'
for micNr in [1,2,3,4]:
    keyname = 'mic{}'.format(micNr)
    createAndStoreTestData(wvPts, baseDir, fileDate, micNr, filename, keyname)

LOG('Klaar: spectra voor testdata Studio', True)
# Out:
# ####################################
# #
# # maak spectra voor testdata Studio
# #
# ####################################
# /opt/miniconda2/envs/py36h2o/lib/python3.6/site-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)
# /opt/miniconda2/envs/py36h2o/lib/python3.6/site-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)
# Klaar: spectra voor testdata Studio

# %%
LOG_HEADER('maak spectra voor testdata G428', True)
wvPts = readSoundChunksDynamic('chunks.G428.soundChunks')
baseDir = recordingDir + '/20170221'
fileDate = 170221
filename = 'testData_G428'
for micNr in [1,2,3,4]:
    keyname = 'mic{}'.format(micNr)
    createAndStoreTestData(wvPts, baseDir, fileDate, micNr, filename, keyname)

LOG('Klaar: spectra voor testdata G428', True)

LOG_HEADER('maak spectra voor testdata G527', True)
wvPts = readSoundChunksDynamic('chunks.G527.soundChunks')
baseDir = recordingDir + '/20170221'
fileDate = 170221
filename = 'testData_G527'
for micNr in [1,2,3,4]:
    keyname = 'mic{}'.format(micNr)
    createAndStoreTestData(wvPts, baseDir, fileDate, micNr, filename, keyname)

LOG('Klaar: spectra voor testdata G527', True)
# Out:
# ####################################
# #
# # maak spectra voor testdata G428
# #
# ####################################
# /opt/miniconda2/envs/py36h2o/lib/python3.6/site-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)
# Klaar: spectra voor testdata G428
# ####################################
# #
# # maak spectra voor testdata G527
# #
# ####################################
#
# Klaar: spectra voor testdata G527

# %% [markdown]
# ## Voer tests uit bij modellen met alle orgs

# %%
# model parameters
modelFilePath = storageFolder
layerss = [[100, 20], [400, 250, 100, 20], [400, 300, 200, 100, 50, 20, 10], [450, 400, 350, 300, 250, 200, 150, 100, 50, 21]]
nrsEpochs = [1,2,3,4,5]

# test data
micNr = 4
testFileNames = ['testData_G428', 'testData_G527', 'testData_Studio']
keyname = 'mic{}'.format(micNr)

for testFileName in testFileNames:
    for layers in layerss:
        for nrEpochs in nrsEpochs:
            testSpecs, testClasses = retrieveTestData(testFileName, keyname)

            LOG_HEADER(getModelName(baseModelFilename, layers, nrEpochs) 
                       + '\n# ' + keyname
                       + '\n# ' + testFileName,
                       True)
            matrix = evaluate_model(testSpecs, testClasses, layers, nrEpochs, modelFilePath, baseModelFilename)
# Out:
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19932     683      24 |  0.97  0.96
# voice           1005   13175     256 |  0.91  0.96
# environment      380      43   12802 |  0.97  0.99
# --------------------------------------
# prec            0.94    0.95    0.98
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19844     754      41 |  0.96  0.96
# voice            953   13235     248 |  0.92  0.96
# environment      232      16   12977 |  0.98  0.99
# --------------------------------------
# prec            0.94    0.95    0.98
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19658     945      36 |  0.95  0.96
# voice            688   13565     183 |  0.94  0.96
# environment      255      37   12933 |  0.98  0.99
# --------------------------------------
# prec            0.95    0.93    0.98
#
# F1 overall: 0.96
# F1 music: 0.95
# F1 voice: 0.94
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep4
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19896     720      23 |  0.96  0.96
# voice            838   13429     169 |  0.93  0.96
# environment      410      38   12777 |  0.97  0.99
# --------------------------------------
# prec            0.94    0.95    0.99
#
# F1 overall: 0.96
# F1 music: 0.95
# F1 voice: 0.94
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep5
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19978     630      31 |  0.97  0.96
# voice            994   13259     183 |  0.92  0.96
# environment      366      37   12822 |  0.97  0.99
# --------------------------------------
# prec            0.94    0.95    0.98
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19684     917      38 |  0.95  0.95
# voice            738   13539     159 |  0.94  0.96
# environment      660      60   12505 |  0.95  0.98
# --------------------------------------
# prec            0.93    0.93    0.98
#
# F1 overall: 0.95
# F1 music: 0.94
# F1 voice: 0.94
# F1 environment: 0.96
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19670     933      36 |  0.95  0.96
# voice            761   13483     192 |  0.93  0.96
# environment      442      37   12746 |  0.96  0.99
# --------------------------------------
# prec            0.94    0.93    0.98
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19847     759      33 |  0.96  0.96
# voice           1015   13263     158 |  0.92  0.96
# environment      217      38   12970 |  0.98  0.99
# --------------------------------------
# prec            0.94    0.94    0.99
#
# F1 overall: 0.96
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep4
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19842     773      24 |  0.96  0.96
# voice            556   13734     146 |  0.95  0.97
# environment      800      34   12391 |  0.94  0.98
# --------------------------------------
# prec            0.94    0.94    0.99
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.95
# F1 environment: 0.96
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep5
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20065     535      39 |  0.97  0.95
# voice           1256   13000     180 |  0.90  0.96
# environment      460      22   12743 |  0.96  0.99
# --------------------------------------
# prec            0.92    0.96    0.98
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19879     720      40 |  0.96  0.95
# voice            933   13297     206 |  0.92  0.96
# environment      828      21   12376 |  0.94  0.98
# --------------------------------------
# prec            0.92    0.95    0.98
#
# F1 overall: 0.94
# F1 music: 0.94
# F1 voice: 0.93
# F1 environment: 0.96
#
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19956     655      28 |  0.97  0.96
# voice            765   13507     164 |  0.94  0.97
# environment      440      51   12734 |  0.96  0.99
# --------------------------------------
# prec            0.94    0.95    0.99
#
# F1 overall: 0.96
# F1 music: 0.95
# F1 voice: 0.94
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20042     548      49 |  0.97  0.95
# voice           1232   13033     171 |  0.90  0.96
# environment      663      14   12548 |  0.95  0.98
# --------------------------------------
# prec            0.91    0.96    0.98
#
# F1 overall: 0.95
# F1 music: 0.94
# F1 voice: 0.93
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep4
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19785     802      52 |  0.96  0.96
# voice            594   13660     182 |  0.95  0.97
# environment      639      50   12536 |  0.95  0.98
# --------------------------------------
# prec            0.94    0.94    0.98
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.94
# F1 environment: 0.96
#
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep5
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19908     693      38 |  0.96  0.96
# voice            677   13614     145 |  0.94  0.97
# environment      562      15   12648 |  0.96  0.98
# --------------------------------------
# prec            0.94    0.95    0.99
#
# F1 overall: 0.96
# F1 music: 0.95
# F1 voice: 0.95
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19792     825      22 |  0.96  0.96
# voice            679   13557     200 |  0.94  0.96
# environment      389      31   12805 |  0.97  0.99
# --------------------------------------
# prec            0.95    0.94    0.98
#
# F1 overall: 0.96
# F1 music: 0.95
# F1 voice: 0.94
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19989     622      28 |  0.97  0.95
# voice           1442   12779     215 |  0.89  0.95
# environment      352      44   12829 |  0.97  0.99
# --------------------------------------
# prec            0.92    0.95    0.98
#
# F1 overall: 0.94
# F1 music: 0.94
# F1 voice: 0.92
# F1 environment: 0.98
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19789     838      12 |  0.96  0.96
# voice            780   13467     189 |  0.93  0.96
# environment      368      66   12791 |  0.97  0.99
# --------------------------------------
# prec            0.95    0.94    0.98
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep4
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20096     536       7 |  0.97  0.93
# voice           1582   12687     167 |  0.88  0.95
# environment     1228      23   11974 |  0.91  0.97
# --------------------------------------
# prec            0.88    0.96    0.99
#
# F1 overall: 0.93
# F1 music: 0.92
# F1 voice: 0.92
# F1 environment: 0.94
#
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep5
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19780     797      62 |  0.96  0.96
# voice            771   13457     208 |  0.93  0.96
# environment      219       9   12997 |  0.98  0.99
# --------------------------------------
# prec            0.95    0.94    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.94
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8819      93       5 |  0.99  0.98
# voice            135    2724       7 |  0.95  0.98
# environment        9       0    2482 |  1.00  1.00
# --------------------------------------
# prec            0.98    0.97    1.00
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.96
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8791     117       9 |  0.99  0.98
# voice            220    2645       1 |  0.92  0.98
# environment        1       0    2490 |  1.00  1.00
# --------------------------------------
# prec            0.98    0.96    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.94
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8710     197      10 |  0.98  0.98
# voice            139    2724       3 |  0.95  0.98
# environment        1       3    2487 |  1.00  1.00
# --------------------------------------
# prec            0.98    0.93    0.99
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.94
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep4
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8813      93      11 |  0.99  0.98
# voice            108    2757       1 |  0.96  0.99
# environment        4       1    2486 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.97    1.00
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.96
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep5
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8824      84       9 |  0.99  0.98
# voice            187    2678       1 |  0.93  0.98
# environment        1       1    2489 |  1.00  1.00
# --------------------------------------
# prec            0.98    0.97    1.00
#
# F1 overall: 0.98
# F1 music: 0.98
# F1 voice: 0.95
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8738     171       8 |  0.98  0.98
# voice            103    2763       0 |  0.96  0.98
# environment        5       4    2482 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.94    1.00
#
# F1 overall: 0.98
# F1 music: 0.98
# F1 voice: 0.95
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8734     176       7 |  0.98  0.98
# voice            152    2714       0 |  0.95  0.98
# environment       12       1    2478 |  0.99  1.00
# --------------------------------------
# prec            0.98    0.94    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.94
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8814      93      10 |  0.99  0.98
# voice            199    2667       0 |  0.93  0.98
# environment        0       0    2491 |  1.00  1.00
# --------------------------------------
# prec            0.98    0.97    1.00
#
# F1 overall: 0.98
# F1 music: 0.98
# F1 voice: 0.95
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep4
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8790     115      12 |  0.99  0.98
# voice             80    2786       0 |  0.97  0.99
# environment       16       0    2475 |  0.99  1.00
# --------------------------------------
# prec            0.99    0.96    1.00
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.97
# F1 environment: 0.99
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep5
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8852      56       9 |  0.99  0.98
# voice            244    2621       1 |  0.91  0.98
# environment        6       0    2485 |  1.00  1.00
# --------------------------------------
# prec            0.97    0.98    1.00
#
# F1 overall: 0.98
# F1 music: 0.98
# F1 voice: 0.95
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8821      89       7 |  0.99  0.98
# voice            188    2675       3 |  0.93  0.98
# environment       17       1    2473 |  0.99  1.00
# --------------------------------------
# prec            0.98    0.97    1.00
#
# F1 overall: 0.98
# F1 music: 0.98
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8807     104       6 |  0.99  0.98
# voice            105    2761       0 |  0.96  0.99
# environment        4       1    2486 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.96    1.00
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.96
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8846      53      18 |  0.99  0.98
# voice            217    2647       2 |  0.92  0.98
# environment       18       1    2472 |  0.99  1.00
# --------------------------------------
# prec            0.97    0.98    0.99
#
# F1 overall: 0.98
# F1 music: 0.98
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep4
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8776     126      15 |  0.98  0.98
# voice             93    2771       2 |  0.97  0.98
# environment        8       2    2481 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.96    0.99
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.96
# F1 environment: 0.99
#
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep5
# # mic4
# # testData_G527
# #
# ####################################
#                    m       v       e |  sens   acc
# music           8796     114       7 |  0.99  0.98
# voice            114    2751       1 |  0.96  0.98
# environment        4       2    2485 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.96    1.00
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.96
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8769     147       1 |  0.98  0.98
# voice             71    2795       0 |  0.98  0.98
# environment       12       2    2477 |  0.99  1.00
# --------------------------------------
# prec            0.99    0.95    1.00
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.96
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8850      62       5 |  0.99  0.97
# voice            382    2482       2 |  0.87  0.97
# environment       14       1    2476 |  0.99  1.00
# --------------------------------------
# prec            0.96    0.98    1.00
#
# F1 overall: 0.96
# F1 music: 0.97
# F1 voice: 0.92
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8768     147       2 |  0.98  0.98
# voice             89    2774       3 |  0.97  0.98
# environment       10       0    2481 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.95    1.00
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.96
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep4
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8872      45       0 |  0.99  0.97
# voice            331    2535       0 |  0.88  0.97
# environment       32       0    2459 |  0.99  1.00
# --------------------------------------
# prec            0.96    0.98    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.93
# F1 environment: 0.99
#
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep5
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8772     133      12 |  0.98  0.98
# voice            105    2760       1 |  0.96  0.98
# environment        0       0    2491 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.95    0.99
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.96
# F1 environment: 1.00
#
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          53394    9113    1088 |  0.84  0.93
# voice            283   36492    1129 |  0.96  0.92
# environment       45     650   41642 |  0.98  0.98
# --------------------------------------
# prec            0.99    0.79    0.95
#
# F1 overall: 0.91
# F1 music: 0.91
# F1 voice: 0.87
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          54440    8047    1108 |  0.86  0.93
# voice            659   36362     883 |  0.96  0.93
# environment       50     483   41804 |  0.99  0.98
# --------------------------------------
# prec            0.99    0.81    0.95
#
# F1 overall: 0.92
# F1 music: 0.92
# F1 voice: 0.88
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          53203    9283    1109 |  0.84  0.93
# voice            243   36983     678 |  0.98  0.93
# environment       39     524   41774 |  0.99  0.98
# --------------------------------------
# prec            0.99    0.79    0.96
#
# F1 overall: 0.92
# F1 music: 0.91
# F1 voice: 0.87
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep4
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          56044    6756     795 |  0.88  0.94
# voice            398   37113     393 |  0.98  0.94
# environment       74     761   41502 |  0.98  0.99
# --------------------------------------
# prec            0.99    0.83    0.97
#
# F1 overall: 0.94
# F1 music: 0.93
# F1 voice: 0.90
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_100_20ep5
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          56327    6314     954 |  0.89  0.94
# voice            678   36701     525 |  0.97  0.94
# environment       51     541   41745 |  0.99  0.99
# --------------------------------------
# prec            0.99    0.84    0.97
#
# F1 overall: 0.94
# F1 music: 0.93
# F1 voice: 0.90
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          54729    7843    1023 |  0.86  0.93
# voice            768   36798     338 |  0.97  0.93
# environment       43     923   41371 |  0.98  0.98
# --------------------------------------
# prec            0.99    0.81    0.97
#
# F1 overall: 0.92
# F1 music: 0.92
# F1 voice: 0.88
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          55270    7401     924 |  0.87  0.94
# voice            496   36610     798 |  0.97  0.94
# environment       84     438   41815 |  0.99  0.98
# --------------------------------------
# prec            0.99    0.82    0.96
#
# F1 overall: 0.93
# F1 music: 0.93
# F1 voice: 0.89
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          55637    6913    1045 |  0.87  0.94
# voice           1268   36283     353 |  0.96  0.94
# environment       76     699   41562 |  0.98  0.98
# --------------------------------------
# prec            0.98    0.83    0.97
#
# F1 overall: 0.93
# F1 music: 0.92
# F1 voice: 0.89
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep4
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          55990    6983     622 |  0.88  0.94
# voice            519   37033     352 |  0.98  0.94
# environment      101     601   41635 |  0.98  0.99
# --------------------------------------
# prec            0.99    0.83    0.98
#
# F1 overall: 0.94
# F1 music: 0.93
# F1 voice: 0.90
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_400_250_100_20ep5
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          57261    5596     738 |  0.90  0.95
# voice           1024   36223     657 |  0.96  0.95
# environment      109     432   41796 |  0.99  0.99
# --------------------------------------
# prec            0.98    0.86    0.97
#
# F1 overall: 0.94
# F1 music: 0.94
# F1 voice: 0.90
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          55430    7335     830 |  0.87  0.94
# voice            335   36760     809 |  0.97  0.94
# environment      153     622   41562 |  0.98  0.98
# --------------------------------------
# prec            0.99    0.82    0.96
#
# F1 overall: 0.93
# F1 music: 0.93
# F1 voice: 0.89
# F1 environment: 0.97
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          55970    6927     698 |  0.88  0.94
# voice            657   36825     422 |  0.97  0.94
# environment      173     743   41421 |  0.98  0.99
# --------------------------------------
# prec            0.99    0.83    0.97
#
# F1 overall: 0.93
# F1 music: 0.93
# F1 voice: 0.89
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          57939    5035     621 |  0.91  0.94
# voice           2759   34628     517 |  0.91  0.94
# environment       81     494   41762 |  0.99  0.99
# --------------------------------------
# prec            0.95    0.86    0.97
#
# F1 overall: 0.93
# F1 music: 0.93
# F1 voice: 0.89
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep4
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          53866    8473    1256 |  0.85  0.93
# voice            166   37186     552 |  0.98  0.93
# environment       43     533   41761 |  0.99  0.98
# --------------------------------------
# prec            1.00    0.81    0.96
#
# F1 overall: 0.92
# F1 music: 0.92
# F1 voice: 0.88
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_400_300_200_100_50_20_10ep5
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          55075    7453    1067 |  0.87  0.94
# voice            563   36521     820 |  0.96  0.94
# environment       35     490   41812 |  0.99  0.98
# --------------------------------------
# prec            0.99    0.82    0.96
#
# F1 overall: 0.93
# F1 music: 0.92
# F1 voice: 0.89
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          54136    8589     870 |  0.85  0.93
# voice            103   37141     660 |  0.98  0.93
# environment       66     553   41718 |  0.99  0.99
# --------------------------------------
# prec            1.00    0.80    0.96
#
# F1 overall: 0.93
# F1 music: 0.92
# F1 voice: 0.88
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          56275    6187    1133 |  0.88  0.94
# voice            634   36732     538 |  0.97  0.94
# environment       50     600   41687 |  0.98  0.98
# --------------------------------------
# prec            0.99    0.84    0.96
#
# F1 overall: 0.94
# F1 music: 0.93
# F1 voice: 0.90
# F1 environment: 0.97
#
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          54898    8091     606 |  0.86  0.94
# voice            315   37156     433 |  0.98  0.93
# environment       71     789   41477 |  0.98  0.99
# --------------------------------------
# prec            0.99    0.81    0.98
#
# F1 overall: 0.93
# F1 music: 0.92
# F1 voice: 0.89
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep4
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          56789    6314     492 |  0.89  0.95
# voice            360   37090     454 |  0.98  0.95
# environment       67     584   41686 |  0.98  0.99
# --------------------------------------
# prec            0.99    0.84    0.98
#
# F1 overall: 0.94
# F1 music: 0.94
# F1 voice: 0.91
# F1 environment: 0.98
#
# ####################################
# #
# # 20180816_orgsHelft1_450_400_350_300_250_200_150_100_50_21ep5
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          55459    7261     875 |  0.87  0.94
# voice           1042   36290     572 |  0.96  0.94
# environment       29     354   41954 |  0.99  0.99
# --------------------------------------
# prec            0.98    0.83    0.97
#
# F1 overall: 0.93
# F1 music: 0.92
# F1 voice: 0.89
# F1 environment: 0.98

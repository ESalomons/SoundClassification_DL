# %% [markdown]
# ## Bedoeld om ook de overall waarden te berekenen

# %%
# %reload_ext autoreload
# %autoreload 2
import glob
import importlib
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import scipy.io.wavfile as wv
import scipy.signal as sig
import wave

from datetime import datetime
from keras.models import Sequential, load_model
from keras.layers import Dense

from util import util
from util import WavFileParts
from util.logUtil import LOG, LOG_HEADER
from util.confusionMatrix import ConfusionMatrix
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### globale settings

# %%
classes = ['music', 'voice', 'environment']

macDir = '/Volumes/SAA_DATA/datasets/'
winDir = 'E:/SAA_DATA/'
osDir = winDir
recordingDir = osDir + '/localizationRecordings'

if osDir == winDir:
    storageFolder = 'E:/SAA_DATA/storedData/'
else:
    storageFolder = '/Users/etto/Desktop/storedData/'

baseSrcDir = osDir + 'localizationFiles/20171025AllExtractionsMic4'
orgWavDirs1 = ['G428_0.0_1.4',
              'G527_0.5_1.4',
              'Studio_2.0_4.2'
              ]

orgWavDirs2 = ['G428_2.1_2.4',
              'G527_1.2_5.8',
              'Studio_3.0_2.0'
              ]

orgsG428 = ['G428_0.0_1.4','G428_2.1_2.4']
orgsG527 = ['G527_0.5_1.4','G527_1.2_5.8']
orgsStudio = ['Studio_2.0_4.2','Studio_3.0_2.0']

NFFT = 1024

chunksBaseDir = 'chunks'
rooms = ['Studio', 'G428', 'G527']

# %% [markdown]
# ### utility functies

# %%
def readSoundChunksDynamic(moduleString):
    chunks = importlib.import_module(moduleString).soundChunks
    wfPts = []
    for jsonString in chunks:
        wfPts.append(WavFileParts.WavFilePartFromJson(jsonString))
    return wfPts

def timeFunction(func):
    """
    Aanroep: bijv. fpc = timeFunction(lambda: getFilesPerCategory(srcDir))
    """
    startTime = datetime.now()
    print('Start: ' + startTime.strftime('%H:%M:%S') + '\n=================')

    res = func()
    
    endTime = datetime.now()
    print('\n=================\nEnd: ' + endTime.strftime('%H:%M:%S'))
    print('Time taken: '),
    print(endTime - startTime)
    print()
    
    return res
    
def storeTestData(allSpectros, allClasses, storageName, keyName):
    filename = storageFolder + storageName + '.hd5'
    df = pd.DataFrame(allSpectros)
    df.to_hdf(path_or_buf=filename, key='spectros_' + keyName)

    df = pd.DataFrame(allClasses)
    df.to_hdf(path_or_buf=filename, key='classes_' + keyName)

def retrieveTestData(storageName, keyName):
    filename = storageFolder + storageName + '.hd5'
    specDf = pd.read_hdf(path_or_buf=filename, key='spectros_' + keyName)
    classesDf = pd.read_hdf(path_or_buf=filename, key='classes_' + keyName)
    return specDf.values, classesDf.values

# %% [markdown]
# ### functies tbv trainen

# %%
# Maakt een dictionary aan; per categorie alle files (volledig pad) uit de srcDir
# srcDir is een van de orgWavDirs, bijvoorbeeld
#    localizationFiles/20171025AllExtractionsMic4/G428_0.0_1.4
def getFilesPerCategory(srcDir):
    filesPerCategory = {}
    for catDirLong in glob.glob(srcDir + '/*'):
        catDir = catDirLong.replace('\\', '/')
        catDir = catDir.replace(srcDir + '/', '')

        filesPerCategory[catDir] = []
        for filename in glob.glob(catDirLong + '/*'):
            filename = filename.replace('\\','/')
            filesPerCategory[catDir].append(filename)
    return filesPerCategory

def getFilesPerCatFromMultipleDirs(srcDirs, srcDirsBase=''):
    filesPerCat = {}
    for dirName in srcDirs:
        srcDir = srcDirsBase + '/' + dirName
        fpcNw = getFilesPerCategory(srcDir)
        if not filesPerCat:
            filesPerCat = fpcNw
        else:
            for key in filesPerCat:
                filesPerCat[key] += fpcNw[key]
    return filesPerCat

# %%
# Maakt een dictionary aan; per categorie de spectrogrammen
def getSpectrosFromFilesPerCategory(filesPerCategory):
    spectros = {}
    for clz in classes:
        spectros[clz] = []
        for filename in filesPerCategory[clz]:
            fs, signal = wv.read(filename)
            freq_array, segment_times, spectrogram = sig.spectrogram(x=signal, fs=fs, nfft=NFFT, noverlap=0)
            spectros[clz].append(spectrogram.T)
    return spectros

# %%
def getClassLengths(spectrosPerCat):
    clzLengths = {}
    for clz in classes:
        clzLengths[clz] = sum([np.shape(lst)[0] for lst in spectrosPerCat[clz]])
    return clzLengths

# %%
# verwacht invoer van getSpectrosFromFilesPerCategory
# levert traindata op (X_train en Y_train)
def createTrainDataFromSpectros(spectrosPerCat, clzLengths):
    X_train = np.concatenate(spectrosPerCat[classes[0]], axis=0)
    for i in range(1, len(classes)):
        nwSpectros = np.concatenate(spectrosPerCat[classes[i]], axis=0)
        X_train = np.concatenate((X_train,nwSpectros), axis=0)
    
    # one-hot encoding voor Y_train
    nrFiles = clzLengths[classes[0]]
    Y_train = np.array((np.ones(nrFiles),np.zeros(nrFiles), np.zeros(nrFiles))).T

    nrFiles = clzLengths[classes[1]]
    Y_train_nw = np.array((np.zeros(nrFiles), np.ones(nrFiles), np.zeros(nrFiles))).T
    Y_train = np.concatenate((Y_train, Y_train_nw),axis=0)

    nrFiles = clzLengths[classes[2]]
    Y_train_nw = np.array((np.zeros(nrFiles), np.zeros(nrFiles), np.ones(nrFiles))).T
    Y_train = np.concatenate((Y_train, Y_train_nw),axis=0)
    
    return X_train, Y_train

# %% [markdown]
# ### deep learning model

# %%
def create_model(layersizes):
    # create model
    model = Sequential()
    model.add(Dense(layersizes[0], input_dim=513, activation='relu'))
    for lsize in layersizes[1:]:
        model.add(Dense(lsize, activation='relu'))
    model.add(Dense(3, activation='softmax'))
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
def getModelFileName(modelFilePath, baseModelFilename, layers, nrEpochs):
    modelFilename = modelFilePath + baseModelFilename
    for lsize in layers:
        modelFilename = '{}_{}'.format(modelFilename, lsize)
    modelFilename += 'ep{}'.format(nrEpochs)
    modelFilename += '.hd5'
    return modelFilename

# %%
def getModelName(baseModelFilename, layers, nrEpochs):
    modelFilename = baseModelFilename
    for lsize in layers:
        modelFilename = '{}_{}'.format(modelFilename, lsize)
    modelFilename += 'ep{}'.format(nrEpochs)
    return modelFilename

# %%
def train_model(X_train, Y_train, layers, nrEpochs, modelFilePath, baseModelFilename):
    soundModel = create_model(layers)
    history = timeFunction(lambda: soundModel.fit(X_train,Y_train, epochs=nrEpochs, shuffle=True, verbose=1))
    soundModel.save(getModelFileName(modelFilePath, baseModelFilename, layers, nrEpochs))
    plt.plot(history.history['loss'])
    plt.show()

# %%
def evaluate_model(X_test, realClasses, layers, nrEpochs, modelFilePath, baseModelFilename):
    soundModel = load_model(getModelFileName(modelFilePath, baseModelFilename, layers, nrEpochs))

    # predicted classes
    predictions = soundModel.predict(X_test)
    predClasses = predictions.argmax(axis=1)

    matrix = ConfusionMatrix(classes)
    for vals in zip(realClasses, predClasses):
        matrix.add(int(vals[0]), int(vals[1]), 1)
    LOG(matrix.toString(),True)
    LOG('', True)
    LOG(matrix.toF1String(), True)
    return matrix

# %%
def train_and_evaluate_per_epoch(X_train, Y_train, realClasses, layers, nrEpochs, modelFilePath, baseModelFilename):
    soundModel = create_model(layers)
    for epNr in range(1, nrEpochs+1):
        LOG('\n*****************\n* Epoch nr {}\n*****************\n'.format(epNr), True)
        soundModel.fit(X_train,Y_train, epochs=1, shuffle=True, verbose=1)
        soundModel.save(getModelFileName(modelFilePath, baseModelFilename, layers, epNr))
        evaluate_model(X_train, realClasses, layers, epNr, modelFilePath, baseModelFilename)

# %% [markdown]
# ### functies tbv testen

# %%
def createAndStoreTestData(wavFileParts, baseDir, fileDate, micNr, storeFilename, keyName):
    allSpectros = np.array([])
    allClasses = np.array([])

    for wfPt in wavFileParts: #type: WavFilePart
        if not 'Gunshot' in wfPt.getSoundType():
            filename = baseDir + '/{:d}_{:d}_mono{:d}.wav'.format(fileDate, wfPt.fileNr, micNr)
            fs, signal = wv.read(filename)

            classNr = classes.index(wfPt.getSoundType().lower())
            for soundChunk in wfPt.getSoundChunks(micNr):
                startFrame = int(soundChunk[0] * fs)
                endFrame = int(soundChunk[1] * fs)

                sigChunk = signal[startFrame: endFrame]
                freq_array, segment_times, spectrogram = sig.spectrogram(x=sigChunk, fs=fs, nfft=NFFT, noverlap=0)
                if len(allSpectros) == 0:
                    allSpectros = spectrogram.T
                else:
                    allSpectros = np.append(allSpectros, spectrogram.T, axis=0)
                allClasses = np.append(allClasses, classNr * np.ones(len(segment_times)))
                
    storeTestData(allSpectros, allClasses, storeFilename, keyName)

# %%
def getTrainDataFromFolders(orgWavDirs):
    fpc = getFilesPerCatFromMultipleDirs(orgWavDirs, baseSrcDir)
    spcs = getSpectrosFromFilesPerCategory(fpc)
    clzLengths = getClassLengths(spcs)
    X_train, Y_train = createTrainDataFromSpectros(spcs, clzLengths)
    # real train classes
    realTrainClasses = np.concatenate((np.zeros(clzLengths[classes[0]]), 
                                  np.ones(clzLengths[classes[1]]), 
                                  2*np.ones(clzLengths[classes[2]])))
    return X_train, Y_train, realTrainClasses

# %%
def testModellen(modelFilePath, layerss, micNr, testFileNames, showOverall=True):

    # test data
    keyname = 'mic{}'.format(micNr)

    for layers in layerss:
        for nrEpochs in nrsEpochs:
            overallMatrix = ConfusionMatrix(classes)
            for testFileName in testFileNames:
                testSpecs, testClasses = retrieveTestData(testFileName, keyname)

                LOG_HEADER(getModelName(baseModelFilename, layers, nrEpochs) 
                           + '\n# ' + keyname
                           + '\n# ' + testFileName,
                           True)
                matrix = evaluate_model(testSpecs, testClasses, layers, nrEpochs, modelFilePath, baseModelFilename)
                overallMatrix.addMatrix(matrix.normalizedCopy())
            
            if showOverall:
                overallMatrix = overallMatrix.normalizedCopy()
                LOG_HEADER(getModelName(baseModelFilename, layers, nrEpochs) 
                           + '\n# ' + keyname
                           + '\n# ' + 'testData_Overall',
                           True)
                LOG(overallMatrix.toString(),True)
                LOG('', True)
                LOG(overallMatrix.toF1String(), True)

# %% [markdown]
# ### Opnieuw tests uitvoeren op oude modellen
# * slechts 3 epochs
# * dit keer met overall resultaten

# %%
baseModelFilename = '20180820_allOrgs_dropout'
modelFilePath = storageFolder
logPrefix = 'Alle Orgs redo met dropout'
layersList = [[100, 20], [400, 250, 100, 20], [400, 300, 200, 100, 50, 20, 10], 
              [450, 400, 350, 300, 250, 200, 150, 100, 50, 21]]
nrEpochs = 3
nrsEpochs = [1,2,3]

# %%
# Test alle modellen
testModellen(modelFilePath=storageFolder, 
             layerss=layersList, 
             micNr=4, 
             testFileNames=['testData_G428', 'testData_G527', 'testData_Studio'], 
             showOverall=True)
# Out:
# ####################################
# #
# # 20180820_allOrgs_dropout_100_20ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19994     616      29 |  0.97  0.96
# voice            999   13177     260 |  0.91  0.96
# environment       49      19   13157 |  0.99  0.99
# --------------------------------------
# prec            0.95    0.95    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.93
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_100_20ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8790     123       4 |  0.99  0.97
# voice            226    2636       4 |  0.92  0.98
# environment        4       0    2487 |  1.00  1.00
# --------------------------------------
# prec            0.97    0.96    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.94
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_allOrgs_dropout_100_20ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          55229    7362    1004 |  0.87  0.94
# voice            319   36658     927 |  0.97  0.94
# environment       34     253   42050 |  0.99  0.98
# --------------------------------------
# prec            0.99    0.83    0.96
#
# F1 overall: 0.93
# F1 music: 0.93
# F1 voice: 0.89
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_allOrgs_dropout_100_20ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.94    0.05    0.01 |  0.94  0.96
# voice           0.05    0.93    0.01 |  0.93  0.96
# environment     0.00    0.00    1.00 |  1.00  0.99
# --------------------------------------
# prec            0.95    0.94    0.98
#
# F1 overall: 0.96
# F1 music: 0.94
# F1 voice: 0.94
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_100_20ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19903     713      23 |  0.96  0.97
# voice            640   13603     193 |  0.94  0.97
# environment       38      30   13157 |  0.99  0.99
# --------------------------------------
# prec            0.97    0.95    0.98
#
# F1 overall: 0.97
# F1 music: 0.97
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_100_20ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8811     104       2 |  0.99  0.99
# voice            106    2756       4 |  0.96  0.99
# environment        0       0    2491 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.96    1.00
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.96
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_allOrgs_dropout_100_20ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          56100    6707     788 |  0.88  0.95
# voice            343   36929     632 |  0.97  0.94
# environment       46     316   41975 |  0.99  0.99
# --------------------------------------
# prec            0.99    0.84    0.97
#
# F1 overall: 0.94
# F1 music: 0.93
# F1 voice: 0.90
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_allOrgs_dropout_100_20ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.94    0.05    0.00 |  0.94  0.97
# voice           0.03    0.96    0.01 |  0.96  0.97
# environment     0.00    0.00    1.00 |  1.00  0.99
# --------------------------------------
# prec            0.97    0.95    0.99
#
# F1 overall: 0.97
# F1 music: 0.96
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_100_20ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19875     719      45 |  0.96  0.97
# voice            472   13717     247 |  0.95  0.97
# environment       32      11   13182 |  1.00  0.99
# --------------------------------------
# prec            0.98    0.95    0.98
#
# F1 overall: 0.97
# F1 music: 0.97
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_100_20ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8786     126       5 |  0.99  0.98
# voice             92    2770       4 |  0.97  0.98
# environment        1       0    2490 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.96    1.00
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.96
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_allOrgs_dropout_100_20ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          55239    7227    1129 |  0.87  0.94
# voice            211   36565    1128 |  0.96  0.94
# environment       25     178   42134 |  1.00  0.98
# --------------------------------------
# prec            1.00    0.83    0.95
#
# F1 overall: 0.93
# F1 music: 0.93
# F1 voice: 0.89
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_allOrgs_dropout_100_20ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.94    0.05    0.01 |  0.94  0.97
# voice           0.02    0.96    0.02 |  0.96  0.97
# environment     0.00    0.00    1.00 |  1.00  0.99
# --------------------------------------
# prec            0.97    0.95    0.98
#
# F1 overall: 0.97
# F1 music: 0.96
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_250_100_20ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19664     940      35 |  0.95  0.97
# voice            430   13809     197 |  0.96  0.97
# environment       48      41   13136 |  0.99  0.99
# --------------------------------------
# prec            0.98    0.93    0.98
#
# F1 overall: 0.97
# F1 music: 0.96
# F1 voice: 0.94
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_250_100_20ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8728     186       3 |  0.98  0.98
# voice             73    2792       1 |  0.97  0.98
# environment        4       1    2486 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.94    1.00
#
# F1 overall: 0.98
# F1 music: 0.98
# F1 voice: 0.96
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_250_100_20ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          53599    8968    1028 |  0.84  0.93
# voice            228   36836     840 |  0.97  0.93
# environment       25     339   41973 |  0.99  0.98
# --------------------------------------
# prec            1.00    0.80    0.96
#
# F1 overall: 0.92
# F1 music: 0.91
# F1 voice: 0.88
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_250_100_20ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.92    0.07    0.01 |  0.92  0.97
# voice           0.02    0.97    0.01 |  0.97  0.96
# environment     0.00    0.00    0.99 |  0.99  0.99
# --------------------------------------
# prec            0.98    0.93    0.98
#
# F1 overall: 0.96
# F1 music: 0.95
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_250_100_20ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19868     751      20 |  0.96  0.97
# voice            577   13710     149 |  0.95  0.97
# environment       56      35   13134 |  0.99  0.99
# --------------------------------------
# prec            0.97    0.95    0.99
#
# F1 overall: 0.97
# F1 music: 0.97
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_250_100_20ep2
# # mic4
# # testData_G527
# #
# ####################################
#                    m       v       e |  sens   acc
# music           8776     136       5 |  0.98  0.98
# voice            136    2730       0 |  0.95  0.98
# environment       12       1    2478 |  0.99  1.00
# --------------------------------------
# prec            0.98    0.95    1.00
#
# F1 overall: 0.98
# F1 music: 0.98
# F1 voice: 0.95
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_250_100_20ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          55071    7935     589 |  0.87  0.93
# voice            860   36772     272 |  0.97  0.93
# environment       20     522   41795 |  0.99  0.99
# --------------------------------------
# prec            0.98    0.81    0.98
#
# F1 overall: 0.93
# F1 music: 0.92
# F1 voice: 0.88
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_250_100_20ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.94    0.06    0.00 |  0.94  0.97
# voice           0.04    0.96    0.01 |  0.96  0.96
# environment     0.00    0.01    0.99 |  0.99  0.99
# --------------------------------------
# prec            0.96    0.94    0.99
#
# F1 overall: 0.96
# F1 music: 0.95
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_250_100_20ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19859     761      19 |  0.96  0.97
# voice            602   13672     162 |  0.95  0.97
# environment       47      35   13143 |  0.99  0.99
# --------------------------------------
# prec            0.97    0.94    0.99
#
# F1 overall: 0.97
# F1 music: 0.97
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_250_100_20ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8793     121       3 |  0.99  0.98
# voice            116    2749       1 |  0.96  0.98
# environment        1       0    2490 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.96    1.00
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.96
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_250_100_20ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          57008    6009     578 |  0.90  0.95
# voice            847   36604     453 |  0.97  0.95
# environment       53     364   41920 |  0.99  0.99
# --------------------------------------
# prec            0.98    0.85    0.98
#
# F1 overall: 0.94
# F1 music: 0.94
# F1 voice: 0.91
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_250_100_20ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.95    0.05    0.00 |  0.95  0.97
# voice           0.03    0.96    0.01 |  0.96  0.97
# environment     0.00    0.00    0.99 |  0.99  0.99
# --------------------------------------
# prec            0.96    0.95    0.99
#
# F1 overall: 0.97
# F1 music: 0.96
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20033     558      48 |  0.97  0.95
# voice           1950   12152     334 |  0.84  0.94
# environment       41      13   13171 |  1.00  0.99
# --------------------------------------
# prec            0.91    0.96    0.97
#
# F1 overall: 0.94
# F1 music: 0.94
# F1 voice: 0.89
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8792     118       7 |  0.99  0.96
# voice            467    2391       8 |  0.83  0.96
# environment        3       0    2488 |  1.00  1.00
# --------------------------------------
# prec            0.95    0.95    0.99
#
# F1 overall: 0.95
# F1 music: 0.97
# F1 voice: 0.89
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          56305    5760    1530 |  0.89  0.94
# voice           1401   34851    1652 |  0.92  0.94
# environment       30     227   42080 |  0.99  0.98
# --------------------------------------
# prec            0.98    0.85    0.93
#
# F1 overall: 0.92
# F1 music: 0.93
# F1 voice: 0.89
# F1 environment: 0.96
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.95    0.04    0.01 |  0.95  0.94
# voice           0.11    0.87    0.02 |  0.87  0.94
# environment     0.00    0.00    1.00 |  1.00  0.99
# --------------------------------------
# prec            0.89    0.95    0.97
#
# F1 overall: 0.94
# F1 music: 0.92
# F1 voice: 0.91
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19861     738      40 |  0.96  0.97
# voice            540   13684     212 |  0.95  0.97
# environment       48      30   13147 |  0.99  0.99
# --------------------------------------
# prec            0.97    0.95    0.98
#
# F1 overall: 0.97
# F1 music: 0.97
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8822      91       4 |  0.99  0.99
# voice            108    2755       3 |  0.96  0.99
# environment        4       0    2487 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.97    1.00
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.96
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          55541    7142     912 |  0.87  0.94
# voice            319   36751     834 |  0.97  0.94
# environment       41     358   41938 |  0.99  0.99
# --------------------------------------
# prec            0.99    0.83    0.96
#
# F1 overall: 0.93
# F1 music: 0.93
# F1 voice: 0.89
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.94    0.05    0.01 |  0.94  0.97
# voice           0.03    0.96    0.01 |  0.96  0.97
# environment     0.00    0.00    0.99 |  0.99  0.99
# --------------------------------------
# prec            0.97    0.94    0.98
#
# F1 overall: 0.97
# F1 music: 0.96
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19894     713      32 |  0.96  0.97
# voice            785   13425     226 |  0.93  0.96
# environment       60      16   13149 |  0.99  0.99
# --------------------------------------
# prec            0.96    0.95    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.94
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8792     121       4 |  0.99  0.98
# voice            222    2644       0 |  0.92  0.98
# environment        6       1    2484 |  1.00  1.00
# --------------------------------------
# prec            0.97    0.96    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.94
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_Studio
# #
# ####################################
#                    m       v       e |  sens   acc
# music          56328    6300     967 |  0.89  0.94
# voice           1003   35837    1064 |  0.95  0.94
# environment       36     206   42095 |  0.99  0.98
# --------------------------------------
# prec            0.98    0.85    0.95
#
# F1 overall: 0.93
# F1 music: 0.93
# F1 voice: 0.89
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_allOrgs_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.95    0.05    0.01 |  0.95  0.96
# voice           0.05    0.93    0.01 |  0.93  0.96
# environment     0.00    0.00    1.00 |  1.00  0.99
# --------------------------------------
# prec            0.94    0.95    0.98
#
# F1 overall: 0.96
# F1 music: 0.94
# F1 voice: 0.94
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19832     743      64 |  0.96  0.97
# voice            487   13618     331 |  0.94  0.97
# environment       38       8   13179 |  1.00  0.99
# --------------------------------------
# prec            0.97    0.95    0.97
#
# F1 overall: 0.97
# F1 music: 0.97
# F1 voice: 0.95
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_allOrgs_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8793     117       7 |  0.99  0.98
# voice            112    2743      11 |  0.96  0.98
# environment        5       0    2486 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.96    0.99
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.96
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_allOrgs_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          53499    8387    1709 |  0.84  0.93
# voice             74   35796    2034 |  0.94  0.93
# environment       20     202   42115 |  0.99  0.97
# --------------------------------------
# prec            1.00    0.81    0.92
#
# F1 overall: 0.91
# F1 music: 0.91
# F1 voice: 0.87
# F1 environment: 0.96
#
# ####################################
# #
# # 20180820_allOrgs_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.93    0.06    0.01 |  0.93  0.97
# voice           0.02    0.95    0.03 |  0.95  0.96
# environment     0.00    0.00    1.00 |  1.00  0.99
# --------------------------------------
# prec            0.97    0.94    0.96
#
# F1 overall: 0.96
# F1 music: 0.95
# F1 voice: 0.94
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_allOrgs_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19833     784      22 |  0.96  0.97
# voice            587   13651     198 |  0.95  0.97
# environment      176      46   13003 |  0.98  0.99
# --------------------------------------
# prec            0.96    0.94    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.94
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_allOrgs_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8802     115       0 |  0.99  0.98
# voice            194    2671       1 |  0.93  0.98
# environment       40       3    2448 |  0.98  1.00
# --------------------------------------
# prec            0.97    0.96    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.94
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          52647   10005     943 |  0.83  0.92
# voice            174   36941     789 |  0.97  0.92
# environment       30     461   41846 |  0.99  0.98
# --------------------------------------
# prec            1.00    0.78    0.96
#
# F1 overall: 0.91
# F1 music: 0.90
# F1 voice: 0.87
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_allOrgs_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.93    0.07    0.01 |  0.93  0.96
# voice           0.04    0.95    0.01 |  0.95  0.96
# environment     0.01    0.01    0.98 |  0.98  0.99
# --------------------------------------
# prec            0.95    0.93    0.98
#
# F1 overall: 0.95
# F1 music: 0.94
# F1 voice: 0.94
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_allOrgs_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19821     786      32 |  0.96  0.97
# voice            431   13846     159 |  0.96  0.97
# environment       48      49   13128 |  0.99  0.99
# --------------------------------------
# prec            0.98    0.94    0.99
#
# F1 overall: 0.97
# F1 music: 0.97
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_allOrgs_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8785     131       1 |  0.99  0.99
# voice             78    2788       0 |  0.97  0.99
# environment        4       2    2485 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.95    1.00
#
# F1 overall: 0.98
# F1 music: 0.99
# F1 voice: 0.96
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_allOrgs_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          54424    8263     908 |  0.86  0.94
# voice            143   37183     578 |  0.98  0.93
# environment       25     520   41792 |  0.99  0.99
# --------------------------------------
# prec            1.00    0.81    0.97
#
# F1 overall: 0.93
# F1 music: 0.92
# F1 voice: 0.89
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_allOrgs_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.93    0.06    0.01 |  0.93  0.97
# voice           0.02    0.97    0.01 |  0.97  0.97
# environment     0.00    0.01    0.99 |  0.99  0.99
# --------------------------------------
# prec            0.98    0.94    0.99
#
# F1 overall: 0.97
# F1 music: 0.95
# F1 voice: 0.95
# F1 environment: 0.99

# %%
# G428
baseModelFilename = '20180820_orgG428_dropout'
modelFilePath = storageFolder
logPrefix = 'G428 model redo met dropout'
layersList = [[100, 20], [400, 250, 100, 20], [400, 300, 200, 100, 50, 20, 10], 
              [450, 400, 350, 300, 250, 200, 150, 100, 50, 21]]
nrEpochs = 3
nrsEpochs = [1,2,3]

# Test alle modellen
testModellen(modelFilePath=storageFolder, 
             layerss=layersList, 
             micNr=4, 
             testFileNames=['testData_G428', 'testData_G527', 'testData_Studio'], 
             showOverall=True)
# Out:
# ####################################
# #
# # 20180820_orgG428_dropout_100_20ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19282    1303      54 |  0.93  0.97
# voice            227   13902     307 |  0.96  0.96
# environment       25      53   13147 |  0.99  0.99
# --------------------------------------
# prec            0.99    0.91    0.97
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.94
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_100_20ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8517     390      10 |  0.96  0.97
# voice             97    2760       9 |  0.96  0.97
# environment        1       1    2489 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.88    0.99
#
# F1 overall: 0.96
# F1 music: 0.97
# F1 voice: 0.92
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_orgG428_dropout_100_20ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          36494   25027    2074 |  0.57  0.81
# voice              0   35848    2056 |  0.95  0.81
# environment        8     480   41849 |  0.99  0.97
# --------------------------------------
# prec            1.00    0.58    0.91
#
# F1 overall: 0.80
# F1 music: 0.73
# F1 voice: 0.72
# F1 environment: 0.95
#
# ####################################
# #
# # 20180820_orgG428_dropout_100_20ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.82    0.17    0.01 |  0.82  0.93
# voice           0.02    0.96    0.03 |  0.96  0.93
# environment     0.00    0.01    0.99 |  0.99  0.99
# --------------------------------------
# prec            0.98    0.85    0.96
#
# F1 overall: 0.92
# F1 music: 0.89
# F1 voice: 0.90
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_100_20ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19402    1171      66 |  0.94  0.96
# voice            661   13497     278 |  0.93  0.95
# environment       20      96   13109 |  0.99  0.99
# --------------------------------------
# prec            0.97    0.91    0.97
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.92
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_100_20ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8548     350      19 |  0.96  0.96
# voice            270    2587       9 |  0.90  0.96
# environment        2       3    2486 |  1.00  1.00
# --------------------------------------
# prec            0.97    0.88    0.99
#
# F1 overall: 0.95
# F1 music: 0.96
# F1 voice: 0.89
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgG428_dropout_100_20ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          38824   22264    2507 |  0.61  0.83
# voice             46   36023    1835 |  0.95  0.83
# environment        8    1002   41327 |  0.98  0.96
# --------------------------------------
# prec            1.00    0.61    0.90
#
# F1 overall: 0.81
# F1 music: 0.76
# F1 voice: 0.74
# F1 environment: 0.94
#
# ####################################
# #
# # 20180820_orgG428_dropout_100_20ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.84    0.15    0.01 |  0.84  0.93
# voice           0.05    0.93    0.02 |  0.93  0.92
# environment     0.00    0.01    0.99 |  0.99  0.98
# --------------------------------------
# prec            0.95    0.85    0.96
#
# F1 overall: 0.92
# F1 music: 0.89
# F1 voice: 0.89
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_100_20ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19271    1312      56 |  0.93  0.97
# voice            194   14029     213 |  0.97  0.96
# environment       27     148   13050 |  0.99  0.99
# --------------------------------------
# prec            0.99    0.91    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.94
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_100_20ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8512     388      17 |  0.95  0.97
# voice             85    2781       0 |  0.97  0.97
# environment        4      10    2477 |  0.99  1.00
# --------------------------------------
# prec            0.99    0.87    0.99
#
# F1 overall: 0.96
# F1 music: 0.97
# F1 voice: 0.92
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgG428_dropout_100_20ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          37399   23591    2605 |  0.59  0.82
# voice             62   36571    1271 |  0.96  0.81
# environment        8    2594   39735 |  0.94  0.95
# --------------------------------------
# prec            1.00    0.58    0.91
#
# F1 overall: 0.80
# F1 music: 0.74
# F1 voice: 0.73
# F1 environment: 0.92
#
# ####################################
# #
# # 20180820_orgG428_dropout_100_20ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.83    0.16    0.02 |  0.83  0.94
# voice           0.01    0.97    0.02 |  0.97  0.93
# environment     0.00    0.03    0.97 |  0.97  0.98
# --------------------------------------
# prec            0.98    0.84    0.97
#
# F1 overall: 0.92
# F1 music: 0.90
# F1 voice: 0.90
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_250_100_20ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19271    1294      74 |  0.93  0.97
# voice            186   14018     232 |  0.97  0.96
# environment       21     112   13092 |  0.99  0.99
# --------------------------------------
# prec            0.99    0.91    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.94
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_250_100_20ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8520     379      18 |  0.96  0.97
# voice             79    2778       9 |  0.97  0.97
# environment        0       6    2485 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.88    0.99
#
# F1 overall: 0.96
# F1 music: 0.97
# F1 voice: 0.92
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_250_100_20ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          37375   23047    3173 |  0.59  0.82
# voice              0   36246    1658 |  0.96  0.82
# environment        6    1175   41156 |  0.97  0.96
# --------------------------------------
# prec            1.00    0.60    0.89
#
# F1 overall: 0.80
# F1 music: 0.74
# F1 voice: 0.74
# F1 environment: 0.93
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_250_100_20ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.83    0.16    0.02 |  0.83  0.94
# voice           0.01    0.97    0.02 |  0.97  0.93
# environment     0.00    0.01    0.99 |  0.99  0.98
# --------------------------------------
# prec            0.98    0.85    0.96
#
# F1 overall: 0.93
# F1 music: 0.90
# F1 voice: 0.90
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_250_100_20ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19435    1156      48 |  0.94  0.97
# voice            289   13994     153 |  0.97  0.96
# environment       34     180   13011 |  0.98  0.99
# --------------------------------------
# prec            0.98    0.91    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.94
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_250_100_20ep2
# # mic4
# # testData_G527
# #
# ####################################
#                    m       v       e |  sens   acc
# music           8588     305      24 |  0.96  0.97
# voice             62    2802       2 |  0.98  0.97
# environment        3      10    2478 |  0.99  1.00
# --------------------------------------
# prec            0.99    0.90    0.99
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.94
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_250_100_20ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          40584   20560    2451 |  0.64  0.84
# voice            236   36443    1225 |  0.96  0.82
# environment       11    4432   37894 |  0.90  0.94
# --------------------------------------
# prec            0.99    0.59    0.91
#
# F1 overall: 0.80
# F1 music: 0.78
# F1 voice: 0.73
# F1 environment: 0.90
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_250_100_20ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.85    0.14    0.01 |  0.85  0.94
# voice           0.02    0.97    0.01 |  0.97  0.93
# environment     0.00    0.04    0.96 |  0.96  0.98
# --------------------------------------
# prec            0.98    0.84    0.97
#
# F1 overall: 0.93
# F1 music: 0.91
# F1 voice: 0.90
# F1 environment: 0.96
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_250_100_20ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19294    1286      59 |  0.93  0.96
# voice            558   13648     230 |  0.95  0.96
# environment       21      97   13107 |  0.99  0.99
# --------------------------------------
# prec            0.97    0.91    0.98
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_250_100_20ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8518     380      19 |  0.96  0.96
# voice            220    2638       8 |  0.92  0.96
# environment        1       2    2488 |  1.00  1.00
# --------------------------------------
# prec            0.97    0.87    0.99
#
# F1 overall: 0.95
# F1 music: 0.96
# F1 voice: 0.90
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_250_100_20ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          39600   21378    2617 |  0.62  0.83
# voice            164   36347    1393 |  0.96  0.83
# environment        7    1419   40911 |  0.97  0.96
# --------------------------------------
# prec            1.00    0.61    0.91
#
# F1 overall: 0.82
# F1 music: 0.77
# F1 voice: 0.75
# F1 environment: 0.94
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_250_100_20ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.84    0.15    0.02 |  0.84  0.93
# voice           0.04    0.94    0.02 |  0.94  0.93
# environment     0.00    0.01    0.99 |  0.99  0.98
# --------------------------------------
# prec            0.95    0.85    0.97
#
# F1 overall: 0.92
# F1 music: 0.89
# F1 voice: 0.90
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19104    1463      72 |  0.93  0.96
# voice            293   13933     210 |  0.97  0.96
# environment       22     165   13038 |  0.99  0.99
# --------------------------------------
# prec            0.98    0.90    0.98
#
# F1 overall: 0.96
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8404     495      18 |  0.94  0.95
# voice            143    2721       2 |  0.95  0.95
# environment        0      12    2479 |  1.00  1.00
# --------------------------------------
# prec            0.98    0.84    0.99
#
# F1 overall: 0.95
# F1 music: 0.96
# F1 voice: 0.89
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          36758   24887    1950 |  0.58  0.81
# voice              3   36196    1705 |  0.95  0.80
# environment        8    2268   40061 |  0.95  0.96
# --------------------------------------
# prec            1.00    0.57    0.92
#
# F1 overall: 0.79
# F1 music: 0.73
# F1 voice: 0.71
# F1 environment: 0.93
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.82    0.17    0.01 |  0.82  0.93
# voice           0.02    0.96    0.02 |  0.96  0.92
# environment     0.00    0.02    0.98 |  0.98  0.98
# --------------------------------------
# prec            0.97    0.83    0.97
#
# F1 overall: 0.92
# F1 music: 0.89
# F1 voice: 0.89
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19406    1177      56 |  0.94  0.96
# voice            599   13662     175 |  0.95  0.96
# environment       30     156   13039 |  0.99  0.99
# --------------------------------------
# prec            0.97    0.91    0.98
#
# F1 overall: 0.96
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8509     394      14 |  0.95  0.95
# voice            258    2606       2 |  0.91  0.95
# environment        2       7    2482 |  1.00  1.00
# --------------------------------------
# prec            0.97    0.87    0.99
#
# F1 overall: 0.95
# F1 music: 0.96
# F1 voice: 0.89
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          40424   20649    2522 |  0.64  0.84
# voice             13   36309    1582 |  0.96  0.82
# environment        8    3130   39199 |  0.93  0.95
# --------------------------------------
# prec            1.00    0.60    0.91
#
# F1 overall: 0.81
# F1 music: 0.78
# F1 voice: 0.74
# F1 environment: 0.92
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.84    0.14    0.01 |  0.84  0.93
# voice           0.04    0.94    0.02 |  0.94  0.92
# environment     0.00    0.03    0.97 |  0.97  0.98
# --------------------------------------
# prec            0.95    0.85    0.97
#
# F1 overall: 0.92
# F1 music: 0.89
# F1 voice: 0.89
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19430    1171      38 |  0.94  0.96
# voice            763   13524     149 |  0.94  0.95
# environment       27     156   13042 |  0.99  0.99
# --------------------------------------
# prec            0.96    0.91    0.99
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.92
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8523     379      15 |  0.96  0.95
# voice            258    2608       0 |  0.91  0.95
# environment        1      10    2480 |  1.00  1.00
# --------------------------------------
# prec            0.97    0.87    0.99
#
# F1 overall: 0.95
# F1 music: 0.96
# F1 voice: 0.89
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_Studio
# #
# ####################################
#                    m       v       e |  sens   acc
# music          40990   20744    1861 |  0.64  0.84
# voice            335   36481    1088 |  0.96  0.83
# environment       10    2786   39541 |  0.93  0.96
# --------------------------------------
# prec            0.99    0.61    0.93
#
# F1 overall: 0.82
# F1 music: 0.78
# F1 voice: 0.75
# F1 environment: 0.93
#
# ####################################
# #
# # 20180820_orgG428_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.85    0.14    0.01 |  0.85  0.93
# voice           0.05    0.94    0.01 |  0.94  0.92
# environment     0.00    0.03    0.97 |  0.97  0.98
# --------------------------------------
# prec            0.94    0.85    0.98
#
# F1 overall: 0.92
# F1 music: 0.89
# F1 voice: 0.89
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG428_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          18746    1803      90 |  0.91  0.96
# voice            175   13986     275 |  0.97  0.95
# environment       13      25   13187 |  1.00  0.99
# --------------------------------------
# prec            0.99    0.88    0.97
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.92
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8212     692      13 |  0.92  0.94
# voice             82    2780       4 |  0.97  0.95
# environment        0       2    2489 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.80    0.99
#
# F1 overall: 0.94
# F1 music: 0.95
# F1 voice: 0.88
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_orgG428_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          30316   30954    2325 |  0.48  0.77
# voice              0   35917    1987 |  0.95  0.77
# environment        5     307   42025 |  0.99  0.97
# --------------------------------------
# prec            1.00    0.53    0.91
#
# F1 overall: 0.76
# F1 music: 0.65
# F1 voice: 0.68
# F1 environment: 0.95
#
# ####################################
# #
# # 20180820_orgG428_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.77    0.22    0.01 |  0.77  0.92
# voice           0.01    0.96    0.02 |  0.96  0.91
# environment     0.00    0.00    1.00 |  1.00  0.99
# --------------------------------------
# prec            0.98    0.81    0.96
#
# F1 overall: 0.91
# F1 music: 0.86
# F1 voice: 0.88
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          18908    1708      23 |  0.92  0.96
# voice             53   14129     254 |  0.98  0.96
# environment       35     143   13047 |  0.99  0.99
# --------------------------------------
# prec            1.00    0.88    0.98
#
# F1 overall: 0.96
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8319     591       7 |  0.93  0.96
# voice             12    2845       9 |  0.99  0.96
# environment        1       5    2485 |  1.00  1.00
# --------------------------------------
# prec            1.00    0.83    0.99
#
# F1 overall: 0.95
# F1 music: 0.96
# F1 voice: 0.90
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_orgG428_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          35479   26200    1916 |  0.56  0.80
# voice              0   36218    1686 |  0.96  0.79
# environment        5    1727   40605 |  0.96  0.96
# --------------------------------------
# prec            1.00    0.56    0.92
#
# F1 overall: 0.79
# F1 music: 0.72
# F1 voice: 0.71
# F1 environment: 0.94
#
# ####################################
# #
# # 20180820_orgG428_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.80    0.19    0.01 |  0.80  0.93
# voice           0.00    0.98    0.02 |  0.98  0.92
# environment     0.00    0.02    0.98 |  0.98  0.98
# --------------------------------------
# prec            1.00    0.83    0.97
#
# F1 overall: 0.92
# F1 music: 0.89
# F1 voice: 0.89
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG428_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          18783    1726     130 |  0.91  0.96
# voice             54   14214     168 |  0.98  0.96
# environment       25     176   13024 |  0.98  0.99
# --------------------------------------
# prec            1.00    0.88    0.98
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG428_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8251     619      47 |  0.93  0.95
# voice             36    2827       3 |  0.99  0.95
# environment        0      12    2479 |  1.00  1.00
# --------------------------------------
# prec            1.00    0.82    0.98
#
# F1 overall: 0.95
# F1 music: 0.96
# F1 voice: 0.89
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgG428_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          32560   28385    2650 |  0.51  0.78
# voice              3   36780    1121 |  0.97  0.77
# environment        8    3634   38695 |  0.91  0.95
# --------------------------------------
# prec            1.00    0.53    0.91
#
# F1 overall: 0.76
# F1 music: 0.68
# F1 voice: 0.69
# F1 environment: 0.91
#
# ####################################
# #
# # 20180820_orgG428_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.78    0.20    0.02 |  0.78  0.93
# voice           0.01    0.98    0.01 |  0.98  0.92
# environment     0.00    0.03    0.96 |  0.96  0.98
# --------------------------------------
# prec            0.99    0.81    0.97
#
# F1 overall: 0.91
# F1 music: 0.87
# F1 voice: 0.89
# F1 environment: 0.97

# %%
# G527
baseModelFilename = '20180820_orgG527_dropout'
modelFilePath = storageFolder
logPrefix = 'G527 model redo met dropout'
layersList = [[100, 20], [400, 250, 100, 20], [400, 300, 200, 100, 50, 20, 10], 
              [450, 400, 350, 300, 250, 200, 150, 100, 50, 21]]
nrEpochs = 3
nrsEpochs = [1,2,3]

# Test alle modellen
testModellen(modelFilePath=storageFolder, 
             layerss=layersList, 
             micNr=4, 
             testFileNames=['testData_G428', 'testData_G527', 'testData_Studio'], 
             showOverall=True)
# Out:
# ####################################
# #
# # 20180820_orgG527_dropout_100_20ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19284    1305      50 |  0.93  0.96
# voice            257   13726     453 |  0.95  0.96
# environment      176      65   12984 |  0.98  0.98
# --------------------------------------
# prec            0.98    0.91    0.96
#
# F1 overall: 0.95
# F1 music: 0.96
# F1 voice: 0.93
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG527_dropout_100_20ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8596     313       8 |  0.96  0.97
# voice             43    2810      13 |  0.98  0.97
# environment        2       0    2489 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.90    0.99
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.94
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_orgG527_dropout_100_20ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          42363   18425    2807 |  0.67  0.85
# voice              1   35675    2228 |  0.94  0.85
# environment       30     881   41426 |  0.98  0.96
# --------------------------------------
# prec            1.00    0.65    0.89
#
# F1 overall: 0.83
# F1 music: 0.80
# F1 voice: 0.77
# F1 environment: 0.93
#
# ####################################
# #
# # 20180820_orgG527_dropout_100_20ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.85    0.13    0.02 |  0.85  0.95
# voice           0.01    0.96    0.03 |  0.96  0.94
# environment     0.00    0.01    0.99 |  0.99  0.98
# --------------------------------------
# prec            0.98    0.87    0.95
#
# F1 overall: 0.93
# F1 music: 0.91
# F1 voice: 0.91
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG527_dropout_100_20ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19833     765      41 |  0.96  0.95
# voice           1194   12820     422 |  0.89  0.95
# environment      334      92   12799 |  0.97  0.98
# --------------------------------------
# prec            0.93    0.94    0.97
#
# F1 overall: 0.94
# F1 music: 0.94
# F1 voice: 0.91
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG527_dropout_100_20ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8821      95       1 |  0.99  0.97
# voice            337    2527       2 |  0.88  0.97
# environment        0       1    2490 |  1.00  1.00
# --------------------------------------
# prec            0.96    0.96    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.92
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_orgG527_dropout_100_20ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          46658   14287    2650 |  0.73  0.88
# voice             95   35514    2295 |  0.94  0.88
# environment       14     751   41572 |  0.98  0.96
# --------------------------------------
# prec            1.00    0.70    0.89
#
# F1 overall: 0.86
# F1 music: 0.85
# F1 voice: 0.80
# F1 environment: 0.94
#
# ####################################
# #
# # 20180820_orgG527_dropout_100_20ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.89    0.09    0.01 |  0.89  0.94
# voice           0.07    0.90    0.03 |  0.90  0.93
# environment     0.01    0.01    0.98 |  0.98  0.98
# --------------------------------------
# prec            0.92    0.90    0.96
#
# F1 overall: 0.93
# F1 music: 0.91
# F1 voice: 0.90
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG527_dropout_100_20ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19743     867      29 |  0.96  0.95
# voice            798   13308     330 |  0.92  0.96
# environment      501     104   12620 |  0.95  0.98
# --------------------------------------
# prec            0.94    0.93    0.97
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.96
#
# ####################################
# #
# # 20180820_orgG527_dropout_100_20ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8801     110       6 |  0.99  0.98
# voice            175    2688       3 |  0.94  0.98
# environment       29       1    2461 |  0.99  1.00
# --------------------------------------
# prec            0.98    0.96    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgG527_dropout_100_20ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          48058   13271    2266 |  0.76  0.89
# voice            178   36259    1467 |  0.96  0.89
# environment       19    1130   41188 |  0.97  0.97
# --------------------------------------
# prec            1.00    0.72    0.92
#
# F1 overall: 0.87
# F1 music: 0.86
# F1 voice: 0.82
# F1 environment: 0.94
#
# ####################################
# #
# # 20180820_orgG527_dropout_100_20ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.90    0.09    0.01 |  0.90  0.95
# voice           0.04    0.94    0.02 |  0.94  0.95
# environment     0.02    0.01    0.97 |  0.97  0.98
# --------------------------------------
# prec            0.94    0.90    0.97
#
# F1 overall: 0.94
# F1 music: 0.92
# F1 voice: 0.92
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_250_100_20ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19727     868      44 |  0.96  0.91
# voice            842   13301     293 |  0.92  0.96
# environment     2703      98   10424 |  0.79  0.94
# --------------------------------------
# prec            0.85    0.93    0.97
#
# F1 overall: 0.90
# F1 music: 0.90
# F1 voice: 0.93
# F1 environment: 0.87
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_250_100_20ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8786     129       2 |  0.99  0.97
# voice            160    2704       2 |  0.94  0.98
# environment      133       3    2355 |  0.95  0.99
# --------------------------------------
# prec            0.97    0.95    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.95
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_250_100_20ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          47704   13864    2027 |  0.75  0.89
# voice             14   35423    2467 |  0.93  0.88
# environment       30     627   41680 |  0.98  0.96
# --------------------------------------
# prec            1.00    0.71    0.90
#
# F1 overall: 0.87
# F1 music: 0.86
# F1 voice: 0.81
# F1 environment: 0.94
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_250_100_20ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.90    0.09    0.01 |  0.90  0.92
# voice           0.04    0.93    0.03 |  0.93  0.94
# environment     0.09    0.01    0.91 |  0.91  0.96
# --------------------------------------
# prec            0.88    0.90    0.96
#
# F1 overall: 0.91
# F1 music: 0.89
# F1 voice: 0.92
# F1 environment: 0.93
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_250_100_20ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19657     878     104 |  0.95  0.96
# voice            628   13442     366 |  0.93  0.96
# environment      234      59   12932 |  0.98  0.98
# --------------------------------------
# prec            0.96    0.93    0.96
#
# F1 overall: 0.95
# F1 music: 0.96
# F1 voice: 0.93
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_250_100_20ep2
# # mic4
# # testData_G527
# #
# ####################################
#                    m       v       e |  sens   acc
# music           8761     130      26 |  0.98  0.97
# voice            210    2655       1 |  0.93  0.98
# environment        1       0    2490 |  1.00  1.00
# --------------------------------------
# prec            0.98    0.95    0.99
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.94
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_250_100_20ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          46628   13819    3148 |  0.73  0.88
# voice            115   36084    1705 |  0.95  0.89
# environment        8     543   41786 |  0.99  0.96
# --------------------------------------
# prec            1.00    0.72    0.90
#
# F1 overall: 0.87
# F1 music: 0.85
# F1 voice: 0.82
# F1 environment: 0.94
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_250_100_20ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.89    0.09    0.02 |  0.89  0.95
# voice           0.04    0.94    0.02 |  0.94  0.95
# environment     0.01    0.01    0.99 |  0.99  0.98
# --------------------------------------
# prec            0.95    0.91    0.96
#
# F1 overall: 0.94
# F1 music: 0.92
# F1 voice: 0.92
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_250_100_20ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19656     922      61 |  0.95  0.96
# voice            475   13633     328 |  0.94  0.96
# environment      514      92   12619 |  0.95  0.98
# --------------------------------------
# prec            0.95    0.93    0.97
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.94
# F1 environment: 0.96
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_250_100_20ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8742     163      12 |  0.98  0.98
# voice            118    2747       1 |  0.96  0.98
# environment        6       0    2485 |  1.00  1.00
# --------------------------------------
# prec            0.99    0.94    0.99
#
# F1 overall: 0.98
# F1 music: 0.98
# F1 voice: 0.95
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_250_100_20ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          46461   14292    2842 |  0.73  0.88
# voice            151   35775    1978 |  0.94  0.88
# environment       17     803   41517 |  0.98  0.96
# --------------------------------------
# prec            1.00    0.70    0.90
#
# F1 overall: 0.86
# F1 music: 0.84
# F1 voice: 0.81
# F1 environment: 0.94
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_250_100_20ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.89    0.10    0.02 |  0.89  0.95
# voice           0.03    0.95    0.03 |  0.95  0.95
# environment     0.01    0.01    0.98 |  0.98  0.98
# --------------------------------------
# prec            0.96    0.90    0.96
#
# F1 overall: 0.94
# F1 music: 0.92
# F1 voice: 0.92
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19586    1032      21 |  0.95  0.93
# voice            680   13468     288 |  0.93  0.96
# environment     1517      83   11625 |  0.88  0.96
# --------------------------------------
# prec            0.90    0.92    0.97
#
# F1 overall: 0.93
# F1 music: 0.92
# F1 voice: 0.93
# F1 environment: 0.92
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8749     166       2 |  0.98  0.97
# voice            123    2742       1 |  0.96  0.98
# environment       83       0    2408 |  0.97  0.99
# --------------------------------------
# prec            0.98    0.94    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.95
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          47223   14913    1459 |  0.74  0.89
# voice             10   36401    1493 |  0.96  0.88
# environment       23     654   41660 |  0.98  0.97
# --------------------------------------
# prec            1.00    0.70    0.93
#
# F1 overall: 0.87
# F1 music: 0.85
# F1 voice: 0.81
# F1 environment: 0.96
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.89    0.10    0.01 |  0.89  0.94
# voice           0.03    0.95    0.02 |  0.95  0.95
# environment     0.05    0.01    0.94 |  0.94  0.97
# --------------------------------------
# prec            0.92    0.90    0.97
#
# F1 overall: 0.93
# F1 music: 0.90
# F1 voice: 0.92
# F1 environment: 0.96
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19609     972      58 |  0.95  0.95
# voice            678   13344     414 |  0.92  0.96
# environment      680      48   12497 |  0.94  0.98
# --------------------------------------
# prec            0.94    0.93    0.96
#
# F1 overall: 0.94
# F1 music: 0.94
# F1 voice: 0.93
# F1 environment: 0.95
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8749     161       7 |  0.98  0.97
# voice            219    2645       2 |  0.92  0.97
# environment        4       2    2485 |  1.00  1.00
# --------------------------------------
# prec            0.98    0.94    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.93
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          46433   14268    2894 |  0.73  0.88
# voice            189   34935    2780 |  0.92  0.88
# environment       12     376   41949 |  0.99  0.96
# --------------------------------------
# prec            1.00    0.70    0.88
#
# F1 overall: 0.86
# F1 music: 0.84
# F1 voice: 0.80
# F1 environment: 0.93
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.89    0.10    0.02 |  0.89  0.94
# voice           0.04    0.92    0.03 |  0.92  0.94
# environment     0.02    0.00    0.98 |  0.98  0.98
# --------------------------------------
# prec            0.94    0.90    0.95
#
# F1 overall: 0.93
# F1 music: 0.91
# F1 voice: 0.91
# F1 environment: 0.96
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19901     686      52 |  0.96  0.94
# voice           1301   12829     306 |  0.89  0.95
# environment      647      97   12481 |  0.94  0.98
# --------------------------------------
# prec            0.91    0.94    0.97
#
# F1 overall: 0.94
# F1 music: 0.94
# F1 voice: 0.91
# F1 environment: 0.96
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8822      93       2 |  0.99  0.97
# voice            325    2540       1 |  0.89  0.97
# environment        4       0    2487 |  1.00  1.00
# --------------------------------------
# prec            0.96    0.96    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.92
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_Studio
# #
# ####################################
#                    m       v       e |  sens   acc
# music          50288   11463    1844 |  0.79  0.90
# voice           1260   34567    2077 |  0.91  0.89
# environment       19     908   41410 |  0.98  0.97
# --------------------------------------
# prec            0.98    0.74    0.91
#
# F1 overall: 0.88
# F1 music: 0.87
# F1 voice: 0.81
# F1 environment: 0.94
#
# ####################################
# #
# # 20180820_orgG527_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.91    0.07    0.01 |  0.91  0.94
# voice           0.08    0.90    0.03 |  0.90  0.94
# environment     0.02    0.01    0.97 |  0.97  0.98
# --------------------------------------
# prec            0.91    0.91    0.96
#
# F1 overall: 0.93
# F1 music: 0.91
# F1 voice: 0.90
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG527_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19581    1033      25 |  0.95  0.95
# voice            469   13671     296 |  0.95  0.96
# environment      678     146   12401 |  0.94  0.98
# --------------------------------------
# prec            0.94    0.92    0.97
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.93
# F1 environment: 0.96
#
# ####################################
# #
# # 20180820_orgG527_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8739     175       3 |  0.98  0.98
# voice            121    2738       7 |  0.96  0.98
# environment       11       9    2471 |  0.99  1.00
# --------------------------------------
# prec            0.99    0.94    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.95
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgG527_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          43242   18668    1685 |  0.68  0.86
# voice              4   36164    1736 |  0.95  0.85
# environment       10    1340   40987 |  0.97  0.97
# --------------------------------------
# prec            1.00    0.64    0.92
#
# F1 overall: 0.84
# F1 music: 0.81
# F1 voice: 0.77
# F1 environment: 0.94
#
# ####################################
# #
# # 20180820_orgG527_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.87    0.12    0.01 |  0.87  0.94
# voice           0.02    0.95    0.02 |  0.95  0.94
# environment     0.02    0.02    0.97 |  0.97  0.98
# --------------------------------------
# prec            0.95    0.87    0.97
#
# F1 overall: 0.93
# F1 music: 0.91
# F1 voice: 0.91
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG527_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19792     762      85 |  0.96  0.96
# voice            875   13125     436 |  0.91  0.96
# environment      451      77   12697 |  0.96  0.98
# --------------------------------------
# prec            0.94    0.94    0.96
#
# F1 overall: 0.94
# F1 music: 0.95
# F1 voice: 0.92
# F1 environment: 0.96
#
# ####################################
# #
# # 20180820_orgG527_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8801     108       8 |  0.99  0.97
# voice            252    2610       4 |  0.91  0.97
# environment        6       1    2484 |  1.00  1.00
# --------------------------------------
# prec            0.97    0.96    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.93
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_orgG527_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          47650   12231    3714 |  0.75  0.89
# voice             81   35346    2477 |  0.93  0.89
# environment       12     677   41648 |  0.98  0.95
# --------------------------------------
# prec            1.00    0.73    0.87
#
# F1 overall: 0.87
# F1 music: 0.86
# F1 voice: 0.82
# F1 environment: 0.92
#
# ####################################
# #
# # 20180820_orgG527_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.90    0.08    0.02 |  0.90  0.95
# voice           0.05    0.92    0.03 |  0.92  0.94
# environment     0.01    0.01    0.98 |  0.98  0.98
# --------------------------------------
# prec            0.93    0.91    0.95
#
# F1 overall: 0.93
# F1 music: 0.92
# F1 voice: 0.92
# F1 environment: 0.96
#
# ####################################
# #
# # 20180820_orgG527_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          19732     881      26 |  0.96  0.96
# voice            548   13638     250 |  0.94  0.96
# environment      350     109   12766 |  0.97  0.98
# --------------------------------------
# prec            0.96    0.93    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.94
# F1 environment: 0.97
#
# ####################################
# #
# # 20180820_orgG527_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8772     140       5 |  0.98  0.98
# voice            171    2693       2 |  0.94  0.98
# environment        5       1    2485 |  1.00  1.00
# --------------------------------------
# prec            0.98    0.95    1.00
#
# F1 overall: 0.97
# F1 music: 0.98
# F1 voice: 0.94
# F1 environment: 1.00
#
# ####################################
# #
# # 20180820_orgG527_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          47650   14387    1558 |  0.75  0.89
# voice             64   36659    1181 |  0.97  0.88
# environment       20    1414   40903 |  0.97  0.97
# --------------------------------------
# prec            1.00    0.70    0.94
#
# F1 overall: 0.87
# F1 music: 0.86
# F1 voice: 0.81
# F1 environment: 0.95
#
# ####################################
# #
# # 20180820_orgG527_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.90    0.09    0.01 |  0.90  0.95
# voice           0.03    0.95    0.02 |  0.95  0.95
# environment     0.01    0.01    0.98 |  0.98  0.98
# --------------------------------------
# prec            0.95    0.90    0.97
#
# F1 overall: 0.94
# F1 music: 0.92
# F1 voice: 0.92
# F1 environment: 0.98

# %%
# Studio
baseModelFilename = '20180820_orgStudio_dropout'
modelFilePath = storageFolder
logPrefix = 'Studio model redo met dropout'
layersList = [[100, 20], [400, 250, 100, 20], [400, 300, 200, 100, 50, 20, 10], 
              [450, 400, 350, 300, 250, 200, 150, 100, 50, 21]]
nrEpochs = 3
nrsEpochs = [1,2,3]

# Test alle modellen
testModellen(modelFilePath=storageFolder, 
             layerss=layersList, 
             micNr=4, 
             testFileNames=['testData_G428', 'testData_G527', 'testData_Studio'], 
             showOverall=True)
# Out:
# ####################################
# #
# # 20180820_orgStudio_dropout_100_20ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20479     154       6 |  0.99  0.86
# voice           4564    9645     227 |  0.67  0.90
# environment     2029      13   11183 |  0.85  0.95
# --------------------------------------
# prec            0.76    0.98    0.98
#
# F1 overall: 0.85
# F1 music: 0.86
# F1 voice: 0.80
# F1 environment: 0.91
#
# ####################################
# #
# # 20180820_orgStudio_dropout_100_20ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8899      18       0 |  1.00  0.92
# voice            830    2027       9 |  0.71  0.94
# environment      255       0    2236 |  0.90  0.98
# --------------------------------------
# prec            0.89    0.99    1.00
#
# F1 overall: 0.90
# F1 music: 0.94
# F1 voice: 0.83
# F1 environment: 0.94
#
# ####################################
# #
# # 20180820_orgStudio_dropout_100_20ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          58641    4689     265 |  0.92  0.95
# voice           1449   35509     946 |  0.94  0.95
# environment       91     125   42121 |  0.99  0.99
# --------------------------------------
# prec            0.97    0.88    0.97
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.91
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgStudio_dropout_100_20ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.97    0.03    0.00 |  0.97  0.89
# voice           0.21    0.77    0.01 |  0.77  0.91
# environment     0.09    0.00    0.91 |  0.91  0.97
# --------------------------------------
# prec            0.76    0.96    0.98
#
# F1 overall: 0.89
# F1 music: 0.85
# F1 voice: 0.86
# F1 environment: 0.95
#
# ####################################
# #
# # 20180820_orgStudio_dropout_100_20ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20413     225       1 |  0.99  0.84
# voice           3929   10361     146 |  0.72  0.91
# environment     3787      11    9427 |  0.71  0.92
# --------------------------------------
# prec            0.73    0.98    0.98
#
# F1 overall: 0.83
# F1 music: 0.84
# F1 voice: 0.83
# F1 environment: 0.83
#
# ####################################
# #
# # 20180820_orgStudio_dropout_100_20ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8904      13       0 |  1.00  0.92
# voice            704    2161       1 |  0.75  0.95
# environment      495       0    1996 |  0.80  0.97
# --------------------------------------
# prec            0.88    0.99    1.00
#
# F1 overall: 0.89
# F1 music: 0.94
# F1 voice: 0.86
# F1 environment: 0.89
#
# ####################################
# #
# # 20180820_orgStudio_dropout_100_20ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          58541    4909     145 |  0.92  0.96
# voice            744   36656     504 |  0.97  0.96
# environment      138     274   41925 |  0.99  0.99
# --------------------------------------
# prec            0.99    0.88    0.98
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.92
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgStudio_dropout_100_20ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.97    0.03    0.00 |  0.97  0.88
# voice           0.18    0.81    0.01 |  0.81  0.93
# environment     0.16    0.00    0.83 |  0.83  0.94
# --------------------------------------
# prec            0.74    0.96    0.99
#
# F1 overall: 0.88
# F1 music: 0.84
# F1 voice: 0.88
# F1 environment: 0.91
#
# ####################################
# #
# # 20180820_orgStudio_dropout_100_20ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20471     166       2 |  0.99  0.82
# voice           5324    8990     122 |  0.62  0.88
# environment     3160      15   10050 |  0.76  0.93
# --------------------------------------
# prec            0.71    0.98    0.99
#
# F1 overall: 0.82
# F1 music: 0.83
# F1 voice: 0.76
# F1 environment: 0.86
#
# ####################################
# #
# # 20180820_orgStudio_dropout_100_20ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8909       8       0 |  1.00  0.90
# voice           1156    1710       0 |  0.60  0.92
# environment      325       0    2166 |  0.87  0.98
# --------------------------------------
# prec            0.86    1.00    1.00
#
# F1 overall: 0.87
# F1 music: 0.92
# F1 voice: 0.75
# F1 environment: 0.93
#
# ####################################
# #
# # 20180820_orgStudio_dropout_100_20ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          59493    3978     124 |  0.94  0.96
# voice           1382   36057     465 |  0.95  0.96
# environment      105     325   41907 |  0.99  0.99
# --------------------------------------
# prec            0.98    0.89    0.99
#
# F1 overall: 0.95
# F1 music: 0.96
# F1 voice: 0.92
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgStudio_dropout_100_20ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.98    0.02    0.00 |  0.98  0.86
# voice           0.27    0.72    0.01 |  0.72  0.90
# environment     0.12    0.00    0.87 |  0.87  0.96
# --------------------------------------
# prec            0.71    0.96    0.99
#
# F1 overall: 0.86
# F1 music: 0.82
# F1 voice: 0.83
# F1 environment: 0.93
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_250_100_20ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20439     192       8 |  0.99  0.85
# voice           4912    9310     214 |  0.64  0.89
# environment     2109      20   11096 |  0.84  0.95
# --------------------------------------
# prec            0.74    0.98    0.98
#
# F1 overall: 0.84
# F1 music: 0.85
# F1 voice: 0.78
# F1 environment: 0.90
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_250_100_20ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8913       3       1 |  1.00  0.91
# voice           1015    1836      15 |  0.64  0.93
# environment      199       0    2292 |  0.92  0.98
# --------------------------------------
# prec            0.88    1.00    0.99
#
# F1 overall: 0.89
# F1 music: 0.94
# F1 voice: 0.78
# F1 environment: 0.96
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_250_100_20ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          59726    3633     236 |  0.94  0.96
# voice           1466   35572     866 |  0.94  0.96
# environment       83     191   42063 |  0.99  0.99
# --------------------------------------
# prec            0.97    0.90    0.97
#
# F1 overall: 0.95
# F1 music: 0.96
# F1 voice: 0.92
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_250_100_20ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.98    0.02    0.00 |  0.98  0.88
# voice           0.24    0.74    0.01 |  0.74  0.91
# environment     0.08    0.00    0.92 |  0.92  0.97
# --------------------------------------
# prec            0.75    0.97    0.98
#
# F1 overall: 0.88
# F1 music: 0.85
# F1 voice: 0.84
# F1 environment: 0.95
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_250_100_20ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20390     244       5 |  0.99  0.82
# voice           4701    9601     134 |  0.67  0.89
# environment     3637      17    9571 |  0.72  0.92
# --------------------------------------
# prec            0.71    0.97    0.99
#
# F1 overall: 0.82
# F1 music: 0.83
# F1 voice: 0.79
# F1 environment: 0.83
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_250_100_20ep2
# # mic4
# # testData_G527
# #
# ####################################
#                    m       v       e |  sens   acc
# music           8911       5       1 |  1.00  0.90
# voice           1074    1788       4 |  0.62  0.92
# environment      369       0    2122 |  0.85  0.97
# --------------------------------------
# prec            0.86    1.00    1.00
#
# F1 overall: 0.87
# F1 music: 0.92
# F1 voice: 0.77
# F1 environment: 0.92
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_250_100_20ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          59686    3775     134 |  0.94  0.96
# voice           1321   36174     409 |  0.95  0.96
# environment       99     402   41836 |  0.99  0.99
# --------------------------------------
# prec            0.98    0.90    0.99
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.92
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_250_100_20ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.98    0.02    0.00 |  0.98  0.86
# voice           0.25    0.75    0.01 |  0.75  0.91
# environment     0.14    0.00    0.85 |  0.85  0.95
# --------------------------------------
# prec            0.72    0.96    0.99
#
# F1 overall: 0.86
# F1 music: 0.83
# F1 voice: 0.84
# F1 environment: 0.92
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_250_100_20ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20384     251       4 |  0.99  0.86
# voice           3510   10794     132 |  0.75  0.92
# environment     3167      12   10046 |  0.76  0.93
# --------------------------------------
# prec            0.75    0.98    0.99
#
# F1 overall: 0.85
# F1 music: 0.85
# F1 voice: 0.85
# F1 environment: 0.86
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_250_100_20ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8909       8       0 |  1.00  0.93
# voice            589    2276       1 |  0.79  0.96
# environment      333       0    2158 |  0.87  0.98
# --------------------------------------
# prec            0.91    1.00    1.00
#
# F1 overall: 0.92
# F1 music: 0.95
# F1 voice: 0.88
# F1 environment: 0.93
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_250_100_20ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          59425    4068     102 |  0.93  0.97
# voice            512   37000     392 |  0.98  0.96
# environment       98     382   41857 |  0.99  0.99
# --------------------------------------
# prec            0.99    0.89    0.99
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.93
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_250_100_20ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.97    0.03    0.00 |  0.97  0.90
# voice           0.15    0.84    0.01 |  0.84  0.94
# environment     0.13    0.00    0.87 |  0.87  0.95
# --------------------------------------
# prec            0.78    0.97    0.99
#
# F1 overall: 0.90
# F1 music: 0.86
# F1 voice: 0.90
# F1 environment: 0.93
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20263     373       3 |  0.98  0.84
# voice           2643   11698      95 |  0.81  0.93
# environment     4826      46    8353 |  0.63  0.90
# --------------------------------------
# prec            0.73    0.97    0.99
#
# F1 overall: 0.83
# F1 music: 0.84
# F1 voice: 0.88
# F1 environment: 0.77
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8888      29       0 |  1.00  0.94
# voice            421    2445       0 |  0.85  0.97
# environment      477       2    2012 |  0.81  0.97
# --------------------------------------
# prec            0.91    0.99    1.00
#
# F1 overall: 0.92
# F1 music: 0.95
# F1 voice: 0.92
# F1 environment: 0.89
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          57369    6135      91 |  0.90  0.95
# voice            715   36818     371 |  0.97  0.95
# environment      246     601   41490 |  0.98  0.99
# --------------------------------------
# prec            0.98    0.85    0.99
#
# F1 overall: 0.94
# F1 music: 0.94
# F1 voice: 0.90
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_300_200_100_50_20_10ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.96    0.04    0.00 |  0.96  0.89
# voice           0.12    0.88    0.01 |  0.88  0.94
# environment     0.19    0.01    0.81 |  0.81  0.93
# --------------------------------------
# prec            0.76    0.95    0.99
#
# F1 overall: 0.88
# F1 music: 0.85
# F1 voice: 0.91
# F1 environment: 0.89
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20362     275       2 |  0.99  0.81
# voice           4267   10062     107 |  0.70  0.90
# environment     4413      21    8791 |  0.66  0.91
# --------------------------------------
# prec            0.70    0.97    0.99
#
# F1 overall: 0.81
# F1 music: 0.82
# F1 voice: 0.81
# F1 environment: 0.79
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8914       3       0 |  1.00  0.91
# voice            848    2017       1 |  0.70  0.94
# environment      448       0    2043 |  0.82  0.97
# --------------------------------------
# prec            0.87    1.00    1.00
#
# F1 overall: 0.89
# F1 music: 0.93
# F1 voice: 0.83
# F1 environment: 0.90
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          59284    4226      85 |  0.93  0.96
# voice            647   36665     592 |  0.97  0.96
# environment      188     397   41752 |  0.99  0.99
# --------------------------------------
# prec            0.99    0.89    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.93
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_300_200_100_50_20_10ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.97    0.03    0.00 |  0.97  0.87
# voice           0.20    0.79    0.01 |  0.79  0.92
# environment     0.17    0.00    0.82 |  0.82  0.94
# --------------------------------------
# prec            0.72    0.96    0.99
#
# F1 overall: 0.87
# F1 music: 0.83
# F1 voice: 0.87
# F1 environment: 0.90
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20228     407       4 |  0.98  0.88
# voice           2619   11687     130 |  0.81  0.93
# environment     2919      23   10283 |  0.78  0.94
# --------------------------------------
# prec            0.79    0.96    0.99
#
# F1 overall: 0.87
# F1 music: 0.87
# F1 voice: 0.88
# F1 environment: 0.87
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8899      18       0 |  1.00  0.95
# voice            489    2374       3 |  0.83  0.96
# environment      266       0    2225 |  0.89  0.98
# --------------------------------------
# prec            0.92    0.99    1.00
#
# F1 overall: 0.93
# F1 music: 0.96
# F1 voice: 0.90
# F1 environment: 0.94
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_Studio
# #
# ####################################
#                    m       v       e |  sens   acc
# music          58161    5309     125 |  0.91  0.96
# voice            282   37169     453 |  0.98  0.96
# environment       83     383   41871 |  0.99  0.99
# --------------------------------------
# prec            0.99    0.87    0.99
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.92
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgStudio_dropout_400_300_200_100_50_20_10ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.96    0.04    0.00 |  0.96  0.91
# voice           0.12    0.87    0.01 |  0.87  0.94
# environment     0.11    0.00    0.89 |  0.89  0.96
# --------------------------------------
# prec            0.81    0.96    0.99
#
# F1 overall: 0.91
# F1 music: 0.88
# F1 voice: 0.91
# F1 environment: 0.94
#
# ####################################
# #
# # 20180820_orgStudio_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20027     607       5 |  0.97  0.82
# voice           3370   10939     127 |  0.76  0.91
# environment     4876      14    8335 |  0.63  0.90
# --------------------------------------
# prec            0.71    0.95    0.98
#
# F1 overall: 0.81
# F1 music: 0.82
# F1 voice: 0.84
# F1 environment: 0.77
#
# ####################################
# #
# # 20180820_orgStudio_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8867      49       1 |  0.99  0.91
# voice            627    2239       0 |  0.78  0.95
# environment      594       0    1897 |  0.76  0.96
# --------------------------------------
# prec            0.88    0.98    1.00
#
# F1 overall: 0.89
# F1 music: 0.93
# F1 voice: 0.87
# F1 environment: 0.86
#
# ####################################
# #
# # 20180820_orgStudio_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          58253    5199     143 |  0.92  0.96
# voice            699   36532     673 |  0.96  0.95
# environment      266     204   41867 |  0.99  0.99
# --------------------------------------
# prec            0.98    0.87    0.98
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.92
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgStudio_dropout_450_400_350_300_250_200_150_100_50_21ep1
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.96    0.04    0.00 |  0.96  0.87
# voice           0.16    0.83    0.01 |  0.83  0.93
# environment     0.20    0.00    0.79 |  0.79  0.93
# --------------------------------------
# prec            0.73    0.95    0.99
#
# F1 overall: 0.87
# F1 music: 0.83
# F1 voice: 0.89
# F1 environment: 0.88
#
# ####################################
# #
# # 20180820_orgStudio_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20409     226       4 |  0.99  0.78
# voice           6168    8169      99 |  0.57  0.86
# environment     4100      58    9067 |  0.69  0.91
# --------------------------------------
# prec            0.67    0.97    0.99
#
# F1 overall: 0.77
# F1 music: 0.80
# F1 voice: 0.71
# F1 environment: 0.81
#
# ####################################
# #
# # 20180820_orgStudio_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8914       3       0 |  1.00  0.86
# voice           1458    1408       0 |  0.49  0.90
# environment      592       0    1899 |  0.76  0.96
# --------------------------------------
# prec            0.81    1.00    1.00
#
# F1 overall: 0.81
# F1 music: 0.90
# F1 voice: 0.66
# F1 environment: 0.87
#
# ####################################
# #
# # 20180820_orgStudio_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          59245    4130     220 |  0.93  0.96
# voice           1170   36482     252 |  0.96  0.96
# environment      281     869   41187 |  0.97  0.99
# --------------------------------------
# prec            0.98    0.88    0.99
#
# F1 overall: 0.95
# F1 music: 0.95
# F1 voice: 0.92
# F1 environment: 0.98
#
# ####################################
# #
# # 20180820_orgStudio_dropout_450_400_350_300_250_200_150_100_50_21ep2
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.97    0.03    0.00 |  0.97  0.82
# voice           0.32    0.67    0.00 |  0.67  0.88
# environment     0.18    0.01    0.81 |  0.81  0.93
# --------------------------------------
# prec            0.66    0.95    0.99
#
# F1 overall: 0.82
# F1 music: 0.78
# F1 voice: 0.79
# F1 environment: 0.89
#
# ####################################
# #
# # 20180820_orgStudio_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_G428
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          20411     216      12 |  0.99  0.88
# voice           3679   10549     208 |  0.73  0.91
# environment     1983      11   11231 |  0.85  0.95
# --------------------------------------
# prec            0.78    0.98    0.98
#
# F1 overall: 0.87
# F1 music: 0.87
# F1 voice: 0.84
# F1 environment: 0.91
#
# ####################################
# #
# # 20180820_orgStudio_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_G527
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           8905       9       3 |  1.00  0.93
# voice            702    2156       8 |  0.75  0.95
# environment      229       0    2262 |  0.91  0.98
# --------------------------------------
# prec            0.91    1.00    1.00
#
# F1 overall: 0.92
# F1 music: 0.95
# F1 voice: 0.86
# F1 environment: 0.95
#
# ####################################
# #
# # 20180820_orgStudio_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_Studio
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music          58680    4466     449 |  0.92  0.96
# voice            446   37015     443 |  0.98  0.96
# environment       47     301   41989 |  0.99  0.99
# --------------------------------------
# prec            0.99    0.89    0.98
#
# F1 overall: 0.96
# F1 music: 0.96
# F1 voice: 0.93
# F1 environment: 0.99
#
# ####################################
# #
# # 20180820_orgStudio_dropout_450_400_350_300_250_200_150_100_50_21ep3
# # mic4
# # testData_Overall
# #
# ####################################
#
#                    m       v       e |  sens   acc
# music           0.97    0.03    0.00 |  0.97  0.91
# voice           0.17    0.82    0.01 |  0.82  0.93
# environment     0.08    0.00    0.92 |  0.92  0.97
# --------------------------------------
# prec            0.79    0.96    0.99
#
# F1 overall: 0.90
# F1 music: 0.87
# F1 voice: 0.89
# F1 environment: 0.95

# %%
from parseExperimentResults import parseRedoExperiment

# %% [raw]
# experimentId='20180820_allOrgs_dropout'
# filePattern='20180824_redoAllOrgs_dropout'
# parseRedoExperiment(experimentId, filePattern)

# %% [raw]
# experimentId='20180820_orgG428_dropout'
# filePattern='20180824_redoG428_dropout'
# parseRedoExperiment(experimentId, filePattern)

# %% [raw]
# experimentId='20180820_orgG527_dropout'
# filePattern='20180824_redoG527_dropout'
# parseRedoExperiment(experimentId, filePattern)

# %% [raw]
# experimentId='20180820_orgStudio_dropout'
# filePattern='20180824_redoStudio_dropout'
# parseRedoExperiment(experimentId, filePattern)
